# %% [markdown]
# <h1>Chapter 6 - Planning & Reflection</h1>
# <i>More Autonomy for your `TinyAgent`</i>
#
#
# <a href="..."><img src="https://img.shields.io/badge/Buy%20the%20Book!-grey?logo=amazon"></a>
# <a href="..."><img src="https://img.shields.io/badge/O'Reilly-white.svg?logo=..."></a>
# <a href="..."><img src="https://img.shields.io/badge/GitHub%20Repository-black?logo=github"></a>
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](...)
#
# ---
#
# This notebook is for Chapter 6 of the [An Illustrated Guide to AI Agents](...) book by [Maarten Grootendorst](https://www.linkedin.com/in/mgrootendorst/) and [Jay Alammar](https://www.linkedin.com/in/jalammar).
#
# ---
#
# <a href="...">
# <img src="https://learning.oreilly.com/covers/urn:orm:book:9798341662681/400w/" width="350"/></a>

# %% [markdown]
# ### **[OPTIONAL]** - Installing Packages on <img src="https://colab.google/static/images/icons/colab.png" width=100>
#
# If you are viewing this notebook on Google Colab (or any other cloud vendor), you need to **uncomment and run** one of the following codeblock to install the dependencies for this chapter. If you want to use a cloud provider, you only need to run the following code block:

# %%
# %%capture
# !pip install illustrated-agents

# %% [markdown]
# ---
#
# 💡 **NOTE**: If you want to use the GPU with `ollama`, then you will have to select a GPU first. In Google Colab, go to
# **Runtime > Change runtime type > Hardware accelerator > GPU > GPU type > T4**.
#
# Then, **uncomment** and run this codeblock:
#
# ---

# %%
# !apt-get install -y zstd > /dev/null 2>&1 && curl -fsSL https://ollama.com/install.sh | sh
# !nohup ollama serve > /dev/null 2>&1 & sleep 3 && ollama pull gemma3:12b &

# %% [markdown]
# # Choosing Your LLM
#
# At the beginning of every chapter, we start by choosing the LLM that we want to use:

# %%
import os
from illustrated_agents.llm import LLM

# Ollama
llm = LLM(model="ollama/gemma3:12b")

# Llama.cpp server
# llm = LLM(model="openai/gemma-3-12b-it-Q4_K_M", api_base="http://localhost:8080", api_key="sk-no-key-required")

# Llama-cpp-python server
# llm = LLM(model="openai/gemma-3-12b-it-Q4_K_M.gguf", api_base="http://localhost:8000/v1/", api_key="sk-no-key-required")

# LM Studio
# llm = LLM(model="lm_studio/gemma-3-12b-it", api_base="http://localhost:1234/v1", api_key="sk-no-key-required")

# Google's Gemini / Gemma
# os.environ['GEMINI_API_KEY'] = "YOUR_GEMINI_API_KEY"
# llm = LLM(model="gemini/gemini-2.5-flash")
# llm = LLM(model="gemini/gemma-3-12b-it")

# %% [markdown]
# # Adding **`Autonomy`**
#
# In the previous chapter, we added the `Tools` module to your `TinyAgent`. In this chapter, we will cover how to give it more autonomy:
#
# ![../images/ch6.png](../images/ch6.png)

# %% [markdown]
# Throughout this notebook we will implement a module that allows for action sequencing, namely Reason and Act (ReAct). Then, we add a reflection module that will check whether the `TinyAgent` is doing the right thing and adjust accordingly.

# %% [markdown]
# # Reason and Act (ReAct)

# %% [markdown]
# Autonomy, as covered in the book, is typically achieved through some method of task decomposition or planning. We are going to use the ReAct framework to give this autonomy to your `TinyAgent`. To do so, we are going to implement loops of:
#
# * `THOUGHT` - A reasoning step about the current situation
# * `ACTION` - An action to execute (e.g., a tool)
# * `OBSERVATION` - A generated observation (typically the output of a tool)
#
# Note that in this example, the `OBSERVATION` will be provided by us and not the LLM. This allows for a more simplified example as it would otherwise need quite a bit of code to add this observation.
#
# ReAct is mostly about prompting the LLM, so that's what we are going to do! The `ReAct` class consists of three functions:
#
# * `system_prompt` - The ReAct prompt
# * `parse_react` - Parse the LLM generated `THOUGHT` and `ACTION` so that they are separated for tool usage
# * `format_observation` - Create the `OBSERVATION` based on the output of the tool
#
# We instruct the `TinyAgent` to always use an `ACTION` and that if it does not need a tool, it can simply return it either as:
#
# * `"intermediate_answer"` - A text output that **does not stop** the `TinyAgent` from running
# * `"final_answer"` - The final answer as text that **stops** the `TinyAgent` from running

# %%
import re


class ReAct:
    """ReACT module."""

    def __init__(self, max_steps: int = 10):
        """Initialize ReAct module.

        Arguments:
            max_steps: Maximum number of ReAct steps to perform.
        """
        self.max_steps = max_steps

    @property
    def system_prompt(self) -> str:
        return """
# ReACT (Reason and Act)

You are a ReAct agent that performs exactly ONE step per turn.
Make sure to break down a given task into smaller steps and decide whether to use a tool or provide a final answer.

## ReACT Format

You use the following format for each step:

THOUGHT: [Your reasoning about what to do next]
ACTION:
{
    "tool": "a_tool_name",
    "args": [...],
}

If no tool is needed and you want to provide an intermediate answer, use:

ACTION:
{
    "tool": "intermediate_answer",
    "args": "insert your intermediate answer here"
}

An observation will be provided after each action. You do not generate the observation yourself.

## ReACT Completion

To provide the final answer to the task, use an action blob with "tool": "final_answer" tool. 
It is the only way to complete the task, else you will be stuck on a loop. So your final output should look like this:

ACTION:
{
    "tool": "final_answer",
    "args": "insert your final answer here"
}

Only use the final_answer tool when you are completely done with all subtasks and have the final answer ready.
"""

    def parse_react(self, text: str) -> dict:
        """Parse a ReAct formatted response into THOUGHT and ACTION."""

        # The patterns for each section
        patterns = {
            "THOUGHT": r"THOUGHT:\s*(.+?)(?=ACTION:|OBSERVATION:|$)",
            "ACTION": r"ACTION:\s*(.+?)(?=THOUGHT:|OBSERVATION:|$)",
        }

        # Extract each section using regex
        result = {}
        for key, pattern in patterns.items():
            match = re.search(pattern, text, re.IGNORECASE | re.DOTALL)
            result[key] = match.group(1).strip() if match else ""

        return result

    def format_observation(self, action: str, observation: str) -> str:
        """Format a tool observation for the conversation."""
        return f"OBSERVATION: {action} -> {observation}"

# %% [markdown]
# There is a lot happening there, so let's go through each function step-by-step starting with the prompt. Since ReAct is mostly a prompting technique, the prompt in itself is the most important step. The prompt, which we crafted through careful trial and error, has several components that describe how your `TinyAgent` should behave. Below, we have annotated this function for you so it is clear what the highlights are. Note that we might update prompt slight, but the general idea should remain the same:

# %%
from illustrated_agents.chapters.ch6a import react_prompt_annotated; react_prompt_annotated
# Out:
# <style>
# pre { line-height: 125%; }
# td.linenos .normal { color: #6e7681; background-color: #0d1117; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #6e7681; background-color: #0d1117; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #e6edf3; background-color: #6e7681; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #e6edf3; background-color: #6e7681; padding-left: 5px; padding-right: 5px; }
# .ca .hll { background-color: #6e7681 }
# .ca { background: #0d1117; color: #E6EDF3 }
# .ca .c { color: #8B949E; font-style: italic } /* Comment */
# .ca .err { color: #F85149 } /* Error */
# .ca .esc { color: #E6EDF3 } /* Escape */
# .ca .g { color: #E6EDF3 } /* Generic */
# .ca .k { color: #FF7B72 } /* Keyword */
# .ca .l { color: #A5D6FF } /* Literal */
# .ca .n { color: #E6EDF3 } /* Name */
# .ca .o { color: #FF7B72; font-weight: bold } /* Operator */
# .ca .x { color: #E6EDF3 } /* Other */
# .ca .p { color: #E6EDF3 } /* Punctuation */
# .ca .ch { color: #8B949E; font-style: italic } /* Comment.Hashbang */
# .ca .cm { color: #8B949E; font-style: italic } /* Comment.Multiline */
# .ca .cp { color: #8B949E; font-weight: bold; font-style: italic } /* Comment.Preproc */
# .ca .cpf { color: #8B949E; font-style: italic } /* Comment.PreprocFile */
# .ca .c1 { color: #8B949E; font-style: italic } /* Comment.Single */
# .ca .cs { color: #8B949E; font-weight: bold; font-style: italic } /* Comment.Special */
# .ca .gd { color: #FFA198; background-color: #490202 } /* Generic.Deleted */
# .ca .ge { color: #E6EDF3; font-style: italic } /* Generic.Emph */
# .ca .ges { color: #E6EDF3; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .ca .gr { color: #FFA198 } /* Generic.Error */
# .ca .gh { color: #79C0FF; font-weight: bold } /* Generic.Heading */
# .ca .gi { color: #56D364; background-color: #0F5323 } /* Generic.Inserted */
# .ca .go { color: #8B949E } /* Generic.Output */
# .ca .gp { color: #8B949E } /* Generic.Prompt */
# .ca .gs { color: #E6EDF3; font-weight: bold } /* Generic.Strong */
# .ca .gu { color: #79C0FF } /* Generic.Subheading */
# .ca .gt { color: #FF7B72 } /* Generic.Traceback */
# .ca .g-Underline { color: #E6EDF3; text-decoration: underline } /* Generic.Underline */
# .ca .kc { color: #79C0FF } /* Keyword.Constant */
# .ca .kd { color: #FF7B72 } /* Keyword.Declaration */
# .ca .kn { color: #FF7B72 } /* Keyword.Namespace */
# .ca .kp { color: #79C0FF } /* Keyword.Pseudo */
# .ca .kr { color: #FF7B72 } /* Keyword.Reserved */
# .ca .kt { color: #FF7B72 } /* Keyword.Type */
# .ca .ld { color: #79C0FF } /* Literal.Date */
# .ca .m { color: #A5D6FF } /* Literal.Number */
# .ca .s { color: #A5D6FF } /* Literal.String */
# .ca .na { color: #E6EDF3 } /* Name.Attribute */
# .ca .nb { color: #E6EDF3 } /* Name.Builtin */
# .ca .nc { color: #F0883E; font-weight: bold } /* Name.Class */
# .ca .no { color: #79C0FF; font-weight: bold } /* Name.Constant */
# .ca .nd { color: #D2A8FF; font-weight: bold } /* Name.Decorator */
# .ca .ni { color: #FFA657 } /* Name.Entity */
# .ca .ne { color: #F0883E; font-weight: bold } /* Name.Exception */
# .ca .nf { color: #D2A8FF; font-weight: bold } /* Name.Function */
# .ca .nl { color: #79C0FF; font-weight: bold } /* Name.Label */
# .ca .nn { color: #FF7B72 } /* Name.Namespace */
# .ca .nx { color: #E6EDF3 } /* Name.Other */
# .ca .py { color: #79C0FF } /* Name.Property */
# .ca .nt { color: #7EE787 } /* Name.Tag */
# .ca .nv { color: #79C0FF } /* Name.Variable */
# .ca .ow { color: #FF7B72; font-weight: bold } /* Operator.Word */
# .ca .pm { color: #E6EDF3 } /* Punctuation.Marker */
# .ca .w { color: #6E7681 } /* Text.Whitespace */
# .ca .mb { color: #A5D6FF } /* Literal.Number.Bin */
# .ca .mf { color: #A5D6FF } /* Literal.Number.Float */
# .ca .mh { color: #A5D6FF } /* Literal.Number.Hex */
# .ca .mi { color: #A5D6FF } /* Literal.Number.Integer */
# .ca .mo { color: #A5D6FF } /* Literal.Number.Oct */
# .ca .sa { color: #79C0FF } /* Literal.String.Affix */
# .ca .sb { color: #A5D6FF } /* Literal.String.Backtick */
# .ca .sc { color: #A5D6FF } /* Literal.String.Char */
# .ca .dl { color: #79C0FF } /* Literal.String.Delimiter */
# .ca .sd { color: #A5D6FF } /* Literal.String.Doc */
# .ca .s2 { color: #A5D6FF } /* Literal.String.Double */
# .ca .se { color: #79C0FF } /* Literal.String.Escape */
# .ca .sh { color: #79C0FF } /* Literal.String.Heredoc */
# .ca .si { color: #A5D6FF } /* Literal.String.Interpol */
# .ca .sx { color: #A5D6FF } /* Literal.String.Other */
# .ca .sr { color: #79C0FF } /* Literal.String.Regex */
# .ca .s1 { color: #A5D6FF } /* Literal.String.Single */
# .ca .ss { color: #A5D6FF } /* Literal.String.Symbol */
# .ca .bp { color: #E6EDF3 } /* Name.Builtin.Pseudo */
# .ca .fm { color: #D2A8FF; font-weight: bold } /* Name.Function.Magic */
# .ca .vc { color: #79C0FF } /* Name.Variable.Class */
# .ca .vg { color: #79C0FF } /* Name.Variable.Global */
# .ca .vi { color: #79C0FF } /* Name.Variable.Instance */
# .ca .vm { color: #79C0FF } /* Name.Variable.Magic */
# .ca .il { color: #A5D6FF } /* Literal.Number.Integer.Long */
# .ca pre{margin:0;line-height:1.5rem}
# .ca .hll{background:#3d4626!important;display:block;width:100%}
# .ca .linenos{background:transparent!important}
# </style>
# <div style="display:inline-flex;background:#0d1117;border-radius:8px;border:1px solid #444;margin:10px 0;font-family:monospace">
# <div style="flex:3;overflow-x:auto"><div class="ca"><pre><span></span><span class="linenos"> 1</span>    <span class="nd">@property</span>
# <span class="linenos"> 2</span>    <span class="k">def</span><span class="w"> </span><span class="nf">prompt</span><span class="p">(</span><span class="bp">self</span><span class="p">)</span> <span class="o">-&gt;</span> <span class="nb">str</span><span class="p">:</span>
# <span class="linenos"> 3</span>        <span class="k">return</span> <span class="s2">&quot;&quot;&quot;</span>
# <span class="linenos"> 4</span><span class="s2"># ReACT (Reason and Act)</span>
# <span class="linenos"> 5</span>
# <span class="hll"><span class="linenos"> 6</span><span class="s2">You are a ReAct agent that performs exactly ONE step per turn.</span>
# </span><span class="hll"><span class="linenos"> 7</span><span class="s2">Make sure to break down a given task into smaller steps and decide whether to use a tool or provide a final answer.</span>
# </span><span class="linenos"> 8</span>
# <span class="linenos"> 9</span><span class="s2">## ReACT Format</span>
# <span class="linenos">10</span>
# <span class="linenos">11</span><span class="s2">You use the following format for each step:</span>
# <span class="linenos">12</span>
# <span class="hll"><span class="linenos">13</span><span class="s2">THOUGHT: [Your reasoning about what to do next]</span>
# </span><span class="hll"><span class="linenos">14</span><span class="s2">ACTION:</span>
# </span><span class="hll"><span class="linenos">15</span><span class="s2">{</span>
# </span><span class="hll"><span class="linenos">16</span><span class="s2">    &quot;tool&quot;: &quot;a_tool_name&quot;,</span>
# </span><span class="hll"><span class="linenos">17</span><span class="s2">    &quot;args&quot;: [...],</span>
# </span><span class="hll"><span class="linenos">18</span><span class="s2">}</span>
# </span><span class="hll"><span class="linenos">19</span>
# </span><span class="linenos">20</span><span class="s2">If no tool is needed and you want to provide an intermediate answer, use:</span>
# <span class="linenos">21</span>
# <span class="hll"><span class="linenos">22</span><span class="s2">ACTION:</span>
# </span><span class="hll"><span class="linenos">23</span><span class="s2">{</span>
# </span><span class="hll"><span class="linenos">24</span><span class="s2">    &quot;tool&quot;: &quot;intermediate_answer&quot;,</span>
# </span><span class="hll"><span class="linenos">25</span><span class="s2">    &quot;args&quot;: &quot;insert your intermediate answer here&quot;</span>
# </span><span class="hll"><span class="linenos">26</span><span class="s2">}</span>
# </span><span class="linenos">27</span>
# <span class="hll"><span class="linenos">28</span><span class="s2">An observation will be provided after each

# %% [markdown]
# The `parse_react` function is needed to parse the strings that contain THOUGHT and ACTION into separate entities:

# %%
from illustrated_agents.chapters.ch6a import react_parse_annotated; react_parse_annotated
# Out:
# <style>
# pre { line-height: 125%; }
# td.linenos .normal { color: #6e7681; background-color: #0d1117; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #6e7681; background-color: #0d1117; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #e6edf3; background-color: #6e7681; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #e6edf3; background-color: #6e7681; padding-left: 5px; padding-right: 5px; }
# .ca .hll { background-color: #6e7681 }
# .ca { background: #0d1117; color: #E6EDF3 }
# .ca .c { color: #8B949E; font-style: italic } /* Comment */
# .ca .err { color: #F85149 } /* Error */
# .ca .esc { color: #E6EDF3 } /* Escape */
# .ca .g { color: #E6EDF3 } /* Generic */
# .ca .k { color: #FF7B72 } /* Keyword */
# .ca .l { color: #A5D6FF } /* Literal */
# .ca .n { color: #E6EDF3 } /* Name */
# .ca .o { color: #FF7B72; font-weight: bold } /* Operator */
# .ca .x { color: #E6EDF3 } /* Other */
# .ca .p { color: #E6EDF3 } /* Punctuation */
# .ca .ch { color: #8B949E; font-style: italic } /* Comment.Hashbang */
# .ca .cm { color: #8B949E; font-style: italic } /* Comment.Multiline */
# .ca .cp { color: #8B949E; font-weight: bold; font-style: italic } /* Comment.Preproc */
# .ca .cpf { color: #8B949E; font-style: italic } /* Comment.PreprocFile */
# .ca .c1 { color: #8B949E; font-style: italic } /* Comment.Single */
# .ca .cs { color: #8B949E; font-weight: bold; font-style: italic } /* Comment.Special */
# .ca .gd { color: #FFA198; background-color: #490202 } /* Generic.Deleted */
# .ca .ge { color: #E6EDF3; font-style: italic } /* Generic.Emph */
# .ca .ges { color: #E6EDF3; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .ca .gr { color: #FFA198 } /* Generic.Error */
# .ca .gh { color: #79C0FF; font-weight: bold } /* Generic.Heading */
# .ca .gi { color: #56D364; background-color: #0F5323 } /* Generic.Inserted */
# .ca .go { color: #8B949E } /* Generic.Output */
# .ca .gp { color: #8B949E } /* Generic.Prompt */
# .ca .gs { color: #E6EDF3; font-weight: bold } /* Generic.Strong */
# .ca .gu { color: #79C0FF } /* Generic.Subheading */
# .ca .gt { color: #FF7B72 } /* Generic.Traceback */
# .ca .g-Underline { color: #E6EDF3; text-decoration: underline } /* Generic.Underline */
# .ca .kc { color: #79C0FF } /* Keyword.Constant */
# .ca .kd { color: #FF7B72 } /* Keyword.Declaration */
# .ca .kn { color: #FF7B72 } /* Keyword.Namespace */
# .ca .kp { color: #79C0FF } /* Keyword.Pseudo */
# .ca .kr { color: #FF7B72 } /* Keyword.Reserved */
# .ca .kt { color: #FF7B72 } /* Keyword.Type */
# .ca .ld { color: #79C0FF } /* Literal.Date */
# .ca .m { color: #A5D6FF } /* Literal.Number */
# .ca .s { color: #A5D6FF } /* Literal.String */
# .ca .na { color: #E6EDF3 } /* Name.Attribute */
# .ca .nb { color: #E6EDF3 } /* Name.Builtin */
# .ca .nc { color: #F0883E; font-weight: bold } /* Name.Class */
# .ca .no { color: #79C0FF; font-weight: bold } /* Name.Constant */
# .ca .nd { color: #D2A8FF; font-weight: bold } /* Name.Decorator */
# .ca .ni { color: #FFA657 } /* Name.Entity */
# .ca .ne { color: #F0883E; font-weight: bold } /* Name.Exception */
# .ca .nf { color: #D2A8FF; font-weight: bold } /* Name.Function */
# .ca .nl { color: #79C0FF; font-weight: bold } /* Name.Label */
# .ca .nn { color: #FF7B72 } /* Name.Namespace */
# .ca .nx { color: #E6EDF3 } /* Name.Other */
# .ca .py { color: #79C0FF } /* Name.Property */
# .ca .nt { color: #7EE787 } /* Name.Tag */
# .ca .nv { color: #79C0FF } /* Name.Variable */
# .ca .ow { color: #FF7B72; font-weight: bold } /* Operator.Word */
# .ca .pm { color: #E6EDF3 } /* Punctuation.Marker */
# .ca .w { color: #6E7681 } /* Text.Whitespace */
# .ca .mb { color: #A5D6FF } /* Literal.Number.Bin */
# .ca .mf { color: #A5D6FF } /* Literal.Number.Float */
# .ca .mh { color: #A5D6FF } /* Literal.Number.Hex */
# .ca .mi { color: #A5D6FF } /* Literal.Number.Integer */
# .ca .mo { color: #A5D6FF } /* Literal.Number.Oct */
# .ca .sa { color: #79C0FF } /* Literal.String.Affix */
# .ca .sb { color: #A5D6FF } /* Literal.String.Backtick */
# .ca .sc { color: #A5D6FF } /* Literal.String.Char */
# .ca .dl { color: #79C0FF } /* Literal.String.Delimiter */
# .ca .sd { color: #A5D6FF } /* Literal.String.Doc */
# .ca .s2 { color: #A5D6FF } /* Literal.String.Double */
# .ca .se { color: #79C0FF } /* Literal.String.Escape */
# .ca .sh { color: #79C0FF } /* Literal.String.Heredoc */
# .ca .si { color: #A5D6FF } /* Literal.String.Interpol */
# .ca .sx { color: #A5D6FF } /* Literal.String.Other */
# .ca .sr { color: #79C0FF } /* Literal.String.Regex */
# .ca .s1 { color: #A5D6FF } /* Literal.String.Single */
# .ca .ss { color: #A5D6FF } /* Literal.String.Symbol */
# .ca .bp { color: #E6EDF3 } /* Name.Builtin.Pseudo */
# .ca .fm { color: #D2A8FF; font-weight: bold } /* Name.Function.Magic */
# .ca .vc { color: #79C0FF } /* Name.Variable.Class */
# .ca .vg { color: #79C0FF } /* Name.Variable.Global */
# .ca .vi { color: #79C0FF } /* Name.Variable.Instance */
# .ca .vm { color: #79C0FF } /* Name.Variable.Magic */
# .ca .il { color: #A5D6FF } /* Literal.Number.Integer.Long */
# .ca pre{margin:0;line-height:1.5rem}
# .ca .hll{background:#3d4626!important;display:block;width:100%}
# .ca .linenos{background:transparent!important}
# </style>
# <div style="display:inline-flex;background:#0d1117;border-radius:8px;border:1px solid #444;margin:10px 0;font-family:monospace">
# <div style="flex:3;overflow-x:auto"><div class="ca"><pre><span></span><span class="linenos"> 1</span><span class="k">def</span><span class="w"> </span><span class="nf">parse_react</span><span class="p">(</span><span class="bp">self</span><span class="p">,</span> <span class="n">text</span><span class="p">:</span> <span class="nb">str</span><span class="p">)</span> <span class="o">-&gt;</span> <span class="nb">dict</span><span class="p">:</span>
# <span class="linenos"> 2</span><span class="w">    </span><span class="sd">&quot;&quot;&quot;Parse a ReAct formatted response into THOUGHT and ACTION.&quot;&quot;&quot;</span>
# <span class="linenos"> 3</span>
# <span class="linenos"> 4</span>    <span class="c1"># The patterns for each section</span>
# <span class="hll"><span class="linenos"> 5</span>    <span class="n">patterns</span> <span class="o">=</span> <span class="p">{</span>
# </span><span class="hll"><span class="linenos"> 6</span>        <span class="s2">&quot;THOUGHT&quot;</span><span class="p">:</span> <span class="sa">r</span><span class="s2">&quot;THOUGHT:\s*(.+?)(?=ACTION:|OBSERVATION:|$)&quot;</span><span class="p">,</span>
# </span><span class="hll"><span class="linenos"> 7</span>        <span class="s2">&quot;ACTION&quot;</span><span class="p">:</span> <span class="sa">r</span><span class="s2">&quot;ACTION:\s*(.+?)(?=THOUGHT:|OBSERVATION:|$)&quot;</span><span class="p">,</span>
# </span><span class="hll"><span class="linenos"> 8</span>    <span class="p">}</span>
# </span><span class="linenos"> 9</span>
# <span class="linenos">10</span>    <span class="c1"># Extract each section using regex</span>
# <span class="linenos">11</span>    <span class="n">result</span> <span class="o">=</span> <span class="p">{}</span>
# <span class="linenos">12</span>    <span class="k">for</span> <span class="n">key</span><span class="p">,</span> <span class="n">pattern</span> <span class="ow">in</span> <span class="n">patterns</span><span class="o">.</span><span class="n">items</span><span class="p">():</span>
# <span class="hll"><span class="linenos">13</span>        <span class="n">match</span> <span class="o">=</span> <span class="n">re</span><span class="o">.</span><span class="n">search</span><span class="p">(</span><span class="n">pattern</span><span class="p">,</span> <span class="n">text</span><span class="p">,</span> <span class="n">re</span><span class="o">.</span><span class="n">IGNORECASE</span> <span class="o">|</span> <span class="n">re</span><span class="o">.</span><span class="n">DOTALL</span><span class="p">)</span>
# </span><span class="hll"><span class="linenos">14</span>        <span class="n">result</span><span class="p">[</span><span class="n">key</span><span class="p">]</span> <span class="o">=</span> <span class="

# %% [markdown]
# The `format_observation` allows us to create the **OBSERVATION** ourselves. In some ReAct frameworks, this is handled by the LLM itself.

# %% [markdown]
# # Updating `agent.py`
#
# There are several changes needed to `TinyAgent` that requires changes throughout the class. In particular:
#
# * `__init__` -- We need to add the prompt of the `ReAct` to the system prompt
# * `run` -- Your `TinyAgent` now runs for a number of steps, defined by `ReAct`
# * `_step` -- Now performs a single step of the `ReAct` loop (**THOUGHT**/**ACTION**/**OBSERVATION**)
# * `_execute_action` -- A function to parse the tool call from the **ACTION** step.

# %%
from illustrated_agents import LLM, Memory, Tools


class TinyAgent:
    """A minimal, modular, and educational agent framework."""

    def __init__(self, llm: LLM, memory: Memory, tools: Tools, planner: ReAct):
        self.llm = llm
        self.memory = memory
        self.tools = tools
        self.planner = planner
        self.reflector = None  # Chapter 6: Add Reflection

        # 0. Tell the LLM about available tools
        system_prompt = "You are a helpful AI agent.\n\n" + self.planner.system_prompt + "\n\n" + self.tools.prompt
        self.memory.add("user", system_prompt)

    def run(self, task: str) -> str:
        """Run the agent on a task."""
        self.memory.add("user", task)

        # ReAct loop
        for step in range(self.planner.max_steps):
            result = self._step()
            if result is not None:
                return result

        return "Max steps reached without completion."

    def _step(self) -> str | None:
        """Perform a single step of the ReAct loop."""
        # Generate response
        output = self.llm.generate(self.memory.get_messages())
        self.memory.add("assistant", output)

        # Parse ReAct response (THOUGHT + ACTION)
        parsed = self.planner.parse_react(output)

        # Execute action if present
        if self.tools.is_tool_call(parsed["ACTION"]):
            return self._execute_action(parsed["ACTION"])

        return None

    def _execute_action(self, action: str) -> str | None:
        """Execute a tool action."""
        tool_call = self.tools.parse_tool_call(action)

        # Final answer ends the loop
        if tool_call["tool"] == "final_answer":
            return tool_call.get("args", "")

        # Execute tool and add observation to memory
        observation = self.tools.run_tool(tool_call)
        obs_prompt = self.planner.format_observation(action, observation)
        self.memory.add("user", obs_prompt)

        return None

# %% [markdown]
# Although we can show the diff like we did before, this time there are so many changes! Instead, let's go through each function and describe how they are used, starting with the `__init__`:

# %%
from illustrated_agents.chapters.ch6a import tinyagent_init_annotated; tinyagent_init_annotated
# Out:
# <style>
# pre { line-height: 125%; }
# td.linenos .normal { color: #6e7681; background-color: #0d1117; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #6e7681; background-color: #0d1117; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #e6edf3; background-color: #6e7681; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #e6edf3; background-color: #6e7681; padding-left: 5px; padding-right: 5px; }
# .ca .hll { background-color: #6e7681 }
# .ca { background: #0d1117; color: #E6EDF3 }
# .ca .c { color: #8B949E; font-style: italic } /* Comment */
# .ca .err { color: #F85149 } /* Error */
# .ca .esc { color: #E6EDF3 } /* Escape */
# .ca .g { color: #E6EDF3 } /* Generic */
# .ca .k { color: #FF7B72 } /* Keyword */
# .ca .l { color: #A5D6FF } /* Literal */
# .ca .n { color: #E6EDF3 } /* Name */
# .ca .o { color: #FF7B72; font-weight: bold } /* Operator */
# .ca .x { color: #E6EDF3 } /* Other */
# .ca .p { color: #E6EDF3 } /* Punctuation */
# .ca .ch { color: #8B949E; font-style: italic } /* Comment.Hashbang */
# .ca .cm { color: #8B949E; font-style: italic } /* Comment.Multiline */
# .ca .cp { color: #8B949E; font-weight: bold; font-style: italic } /* Comment.Preproc */
# .ca .cpf { color: #8B949E; font-style: italic } /* Comment.PreprocFile */
# .ca .c1 { color: #8B949E; font-style: italic } /* Comment.Single */
# .ca .cs { color: #8B949E; font-weight: bold; font-style: italic } /* Comment.Special */
# .ca .gd { color: #FFA198; background-color: #490202 } /* Generic.Deleted */
# .ca .ge { color: #E6EDF3; font-style: italic } /* Generic.Emph */
# .ca .ges { color: #E6EDF3; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .ca .gr { color: #FFA198 } /* Generic.Error */
# .ca .gh { color: #79C0FF; font-weight: bold } /* Generic.Heading */
# .ca .gi { color: #56D364; background-color: #0F5323 } /* Generic.Inserted */
# .ca .go { color: #8B949E } /* Generic.Output */
# .ca .gp { color: #8B949E } /* Generic.Prompt */
# .ca .gs { color: #E6EDF3; font-weight: bold } /* Generic.Strong */
# .ca .gu { color: #79C0FF } /* Generic.Subheading */
# .ca .gt { color: #FF7B72 } /* Generic.Traceback */
# .ca .g-Underline { color: #E6EDF3; text-decoration: underline } /* Generic.Underline */
# .ca .kc { color: #79C0FF } /* Keyword.Constant */
# .ca .kd { color: #FF7B72 } /* Keyword.Declaration */
# .ca .kn { color: #FF7B72 } /* Keyword.Namespace */
# .ca .kp { color: #79C0FF } /* Keyword.Pseudo */
# .ca .kr { color: #FF7B72 } /* Keyword.Reserved */
# .ca .kt { color: #FF7B72 } /* Keyword.Type */
# .ca .ld { color: #79C0FF } /* Literal.Date */
# .ca .m { color: #A5D6FF } /* Literal.Number */
# .ca .s { color: #A5D6FF } /* Literal.String */
# .ca .na { color: #E6EDF3 } /* Name.Attribute */
# .ca .nb { color: #E6EDF3 } /* Name.Builtin */
# .ca .nc { color: #F0883E; font-weight: bold } /* Name.Class */
# .ca .no { color: #79C0FF; font-weight: bold } /* Name.Constant */
# .ca .nd { color: #D2A8FF; font-weight: bold } /* Name.Decorator */
# .ca .ni { color: #FFA657 } /* Name.Entity */
# .ca .ne { color: #F0883E; font-weight: bold } /* Name.Exception */
# .ca .nf { color: #D2A8FF; font-weight: bold } /* Name.Function */
# .ca .nl { color: #79C0FF; font-weight: bold } /* Name.Label */
# .ca .nn { color: #FF7B72 } /* Name.Namespace */
# .ca .nx { color: #E6EDF3 } /* Name.Other */
# .ca .py { color: #79C0FF } /* Name.Property */
# .ca .nt { color: #7EE787 } /* Name.Tag */
# .ca .nv { color: #79C0FF } /* Name.Variable */
# .ca .ow { color: #FF7B72; font-weight: bold } /* Operator.Word */
# .ca .pm { color: #E6EDF3 } /* Punctuation.Marker */
# .ca .w { color: #6E7681 } /* Text.Whitespace */
# .ca .mb { color: #A5D6FF } /* Literal.Number.Bin */
# .ca .mf { color: #A5D6FF } /* Literal.Number.Float */
# .ca .mh { color: #A5D6FF } /* Literal.Number.Hex */
# .ca .mi { color: #A5D6FF } /* Literal.Number.Integer */
# .ca .mo { color: #A5D6FF } /* Literal.Number.Oct */
# .ca .sa { color: #79C0FF } /* Literal.String.Affix */
# .ca .sb { color: #A5D6FF } /* Literal.String.Backtick */
# .ca .sc { color: #A5D6FF } /* Literal.String.Char */
# .ca .dl { color: #79C0FF } /* Literal.String.Delimiter */
# .ca .sd { color: #A5D6FF } /* Literal.String.Doc */
# .ca .s2 { color: #A5D6FF } /* Literal.String.Double */
# .ca .se { color: #79C0FF } /* Literal.String.Escape */
# .ca .sh { color: #79C0FF } /* Literal.String.Heredoc */
# .ca .si { color: #A5D6FF } /* Literal.String.Interpol */
# .ca .sx { color: #A5D6FF } /* Literal.String.Other */
# .ca .sr { color: #79C0FF } /* Literal.String.Regex */
# .ca .s1 { color: #A5D6FF } /* Literal.String.Single */
# .ca .ss { color: #A5D6FF } /* Literal.String.Symbol */
# .ca .bp { color: #E6EDF3 } /* Name.Builtin.Pseudo */
# .ca .fm { color: #D2A8FF; font-weight: bold } /* Name.Function.Magic */
# .ca .vc { color: #79C0FF } /* Name.Variable.Class */
# .ca .vg { color: #79C0FF } /* Name.Variable.Global */
# .ca .vi { color: #79C0FF } /* Name.Variable.Instance */
# .ca .vm { color: #79C0FF } /* Name.Variable.Magic */
# .ca .il { color: #A5D6FF } /* Literal.Number.Integer.Long */
# .ca pre{margin:0;line-height:1.5rem}
# .ca .hll{background:#3d4626!important;display:block;width:100%}
# .ca .linenos{background:transparent!important}
# </style>
# <div style="display:inline-flex;background:#0d1117;border-radius:8px;border:1px solid #444;margin:10px 0;font-family:monospace">
# <div style="flex:3;overflow-x:auto"><div class="ca"><pre><span></span><span class="linenos"> 1</span><span class="k">def</span><span class="w"> </span><span class="fm">__init__</span><span class="p">(</span><span class="bp">self</span><span class="p">,</span> <span class="n">llm</span><span class="p">:</span> <span class="n">LLM</span><span class="p">,</span> <span class="n">memory</span><span class="p">:</span> <span class="n">Memory</span><span class="p">,</span> <span class="n">tools</span><span class="p">:</span> <span class="n">Tools</span><span class="p">,</span> <span class="n">planner</span><span class="p">:</span> <span class="n">ReAct</span><span class="p">):</span>
# <span class="linenos"> 2</span>    <span class="bp">self</span><span class="o">.</span><span class="n">llm</span> <span class="o">=</span> <span class="n">llm</span>
# <span class="linenos"> 3</span>    <span class="bp">self</span><span class="o">.</span><span class="n">memory</span> <span class="o">=</span> <span class="n">memory</span>
# <span class="linenos"> 4</span>    <span class="bp">self</span><span class="o">.</span><span class="n">tools</span> <span class="o">=</span> <span class="n">tools</span>
# <span class="linenos"> 5</span>    <span class="bp">self</span><span class="o">.</span><span class="n">planner</span> <span class="o">=</span> <span class="n">planner</span>
# <span class="linenos"> 6</span>    <span class="bp">self</span><span class="o">.</span><span class="n">reflector</span> <span class="o">=</span> <span class="kc">None</span>  <span class="c1"># Chapter 6: Add Reflection</span>
# <span class="linenos"> 7</span>
# <span class="linenos"> 8</span>    <span class="c1"># 0. Tell the LLM about available tools</span>
# <span class="hll"><span class="linenos"> 9</span>    <span class="n">system_prompt</span> <span class="o">=</span> <span class="s2">&quot;You are a helpful AI agent.</span><span class="se">\n\n</span><span class="s2">&quot;</span> <span class="o">+</span> <span class="bp">self</span><span class="o">.</span><span class="n">planner</span><span class="o">.</span><span class="n">prompt</span> <span class="o">+</span> <span class="s2">&quot;</span><span class="se">\n\n</span><span class="s2">&quot;</span> <span class="o">+</span> <span class="bp">self</span><span class="o">.</span><span class="n">tools</span><span class="o">.</span><span class="n">prompt</span>
# </span><span class="linenos">10</span>    <span class="bp">self</span><span class="o">.</span><span class="n">memory</span><span class="o">.</span><span class="n">add</span><span class="p">(</span><span class="s2">&quot;user&quot;</span><span class="p">,</span> <span class="n">system_prompt</span><span class="p">)</span>
# </pre></div>
# </div>
# <div style="flex:1;mi

# %% [markdown]
# Next, let's explore the `run` function where two interesting actions take place:

# %%
from illustrated_agents.chapters.ch6a import tinyagent_run_annotated; tinyagent_run_annotated
# Out:
# <style>
# pre { line-height: 125%; }
# td.linenos .normal { color: #6e7681; background-color: #0d1117; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #6e7681; background-color: #0d1117; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #e6edf3; background-color: #6e7681; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #e6edf3; background-color: #6e7681; padding-left: 5px; padding-right: 5px; }
# .ca .hll { background-color: #6e7681 }
# .ca { background: #0d1117; color: #E6EDF3 }
# .ca .c { color: #8B949E; font-style: italic } /* Comment */
# .ca .err { color: #F85149 } /* Error */
# .ca .esc { color: #E6EDF3 } /* Escape */
# .ca .g { color: #E6EDF3 } /* Generic */
# .ca .k { color: #FF7B72 } /* Keyword */
# .ca .l { color: #A5D6FF } /* Literal */
# .ca .n { color: #E6EDF3 } /* Name */
# .ca .o { color: #FF7B72; font-weight: bold } /* Operator */
# .ca .x { color: #E6EDF3 } /* Other */
# .ca .p { color: #E6EDF3 } /* Punctuation */
# .ca .ch { color: #8B949E; font-style: italic } /* Comment.Hashbang */
# .ca .cm { color: #8B949E; font-style: italic } /* Comment.Multiline */
# .ca .cp { color: #8B949E; font-weight: bold; font-style: italic } /* Comment.Preproc */
# .ca .cpf { color: #8B949E; font-style: italic } /* Comment.PreprocFile */
# .ca .c1 { color: #8B949E; font-style: italic } /* Comment.Single */
# .ca .cs { color: #8B949E; font-weight: bold; font-style: italic } /* Comment.Special */
# .ca .gd { color: #FFA198; background-color: #490202 } /* Generic.Deleted */
# .ca .ge { color: #E6EDF3; font-style: italic } /* Generic.Emph */
# .ca .ges { color: #E6EDF3; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .ca .gr { color: #FFA198 } /* Generic.Error */
# .ca .gh { color: #79C0FF; font-weight: bold } /* Generic.Heading */
# .ca .gi { color: #56D364; background-color: #0F5323 } /* Generic.Inserted */
# .ca .go { color: #8B949E } /* Generic.Output */
# .ca .gp { color: #8B949E } /* Generic.Prompt */
# .ca .gs { color: #E6EDF3; font-weight: bold } /* Generic.Strong */
# .ca .gu { color: #79C0FF } /* Generic.Subheading */
# .ca .gt { color: #FF7B72 } /* Generic.Traceback */
# .ca .g-Underline { color: #E6EDF3; text-decoration: underline } /* Generic.Underline */
# .ca .kc { color: #79C0FF } /* Keyword.Constant */
# .ca .kd { color: #FF7B72 } /* Keyword.Declaration */
# .ca .kn { color: #FF7B72 } /* Keyword.Namespace */
# .ca .kp { color: #79C0FF } /* Keyword.Pseudo */
# .ca .kr { color: #FF7B72 } /* Keyword.Reserved */
# .ca .kt { color: #FF7B72 } /* Keyword.Type */
# .ca .ld { color: #79C0FF } /* Literal.Date */
# .ca .m { color: #A5D6FF } /* Literal.Number */
# .ca .s { color: #A5D6FF } /* Literal.String */
# .ca .na { color: #E6EDF3 } /* Name.Attribute */
# .ca .nb { color: #E6EDF3 } /* Name.Builtin */
# .ca .nc { color: #F0883E; font-weight: bold } /* Name.Class */
# .ca .no { color: #79C0FF; font-weight: bold } /* Name.Constant */
# .ca .nd { color: #D2A8FF; font-weight: bold } /* Name.Decorator */
# .ca .ni { color: #FFA657 } /* Name.Entity */
# .ca .ne { color: #F0883E; font-weight: bold } /* Name.Exception */
# .ca .nf { color: #D2A8FF; font-weight: bold } /* Name.Function */
# .ca .nl { color: #79C0FF; font-weight: bold } /* Name.Label */
# .ca .nn { color: #FF7B72 } /* Name.Namespace */
# .ca .nx { color: #E6EDF3 } /* Name.Other */
# .ca .py { color: #79C0FF } /* Name.Property */
# .ca .nt { color: #7EE787 } /* Name.Tag */
# .ca .nv { color: #79C0FF } /* Name.Variable */
# .ca .ow { color: #FF7B72; font-weight: bold } /* Operator.Word */
# .ca .pm { color: #E6EDF3 } /* Punctuation.Marker */
# .ca .w { color: #6E7681 } /* Text.Whitespace */
# .ca .mb { color: #A5D6FF } /* Literal.Number.Bin */
# .ca .mf { color: #A5D6FF } /* Literal.Number.Float */
# .ca .mh { color: #A5D6FF } /* Literal.Number.Hex */
# .ca .mi { color: #A5D6FF } /* Literal.Number.Integer */
# .ca .mo { color: #A5D6FF } /* Literal.Number.Oct */
# .ca .sa { color: #79C0FF } /* Literal.String.Affix */
# .ca .sb { color: #A5D6FF } /* Literal.String.Backtick */
# .ca .sc { color: #A5D6FF } /* Literal.String.Char */
# .ca .dl { color: #79C0FF } /* Literal.String.Delimiter */
# .ca .sd { color: #A5D6FF } /* Literal.String.Doc */
# .ca .s2 { color: #A5D6FF } /* Literal.String.Double */
# .ca .se { color: #79C0FF } /* Literal.String.Escape */
# .ca .sh { color: #79C0FF } /* Literal.String.Heredoc */
# .ca .si { color: #A5D6FF } /* Literal.String.Interpol */
# .ca .sx { color: #A5D6FF } /* Literal.String.Other */
# .ca .sr { color: #79C0FF } /* Literal.String.Regex */
# .ca .s1 { color: #A5D6FF } /* Literal.String.Single */
# .ca .ss { color: #A5D6FF } /* Literal.String.Symbol */
# .ca .bp { color: #E6EDF3 } /* Name.Builtin.Pseudo */
# .ca .fm { color: #D2A8FF; font-weight: bold } /* Name.Function.Magic */
# .ca .vc { color: #79C0FF } /* Name.Variable.Class */
# .ca .vg { color: #79C0FF } /* Name.Variable.Global */
# .ca .vi { color: #79C0FF } /* Name.Variable.Instance */
# .ca .vm { color: #79C0FF } /* Name.Variable.Magic */
# .ca .il { color: #A5D6FF } /* Literal.Number.Integer.Long */
# .ca pre{margin:0;line-height:1.5rem}
# .ca .hll{background:#3d4626!important;display:block;width:100%}
# .ca .linenos{background:transparent!important}
# </style>
# <div style="display:inline-flex;background:#0d1117;border-radius:8px;border:1px solid #444;margin:10px 0;font-family:monospace">
# <div style="flex:3;overflow-x:auto"><div class="ca"><pre><span></span><span class="linenos"> 1</span><span class="k">def</span><span class="w"> </span><span class="nf">run</span><span class="p">(</span><span class="bp">self</span><span class="p">,</span> <span class="n">task</span><span class="p">:</span> <span class="nb">str</span><span class="p">)</span> <span class="o">-&gt;</span> <span class="nb">str</span><span class="p">:</span>
# <span class="linenos"> 2</span><span class="w">    </span><span class="sd">&quot;&quot;&quot;Run the agent on a task.&quot;&quot;&quot;</span>
# <span class="hll"><span class="linenos"> 3</span>    <span class="bp">self</span><span class="o">.</span><span class="n">memory</span><span class="o">.</span><span class="n">add</span><span class="p">(</span><span class="s2">&quot;user&quot;</span><span class="p">,</span> <span class="n">task</span><span class="p">)</span>
# </span><span class="linenos"> 4</span>
# <span class="linenos"> 5</span>    <span class="c1"># ReAct loop</span>
# <span class="hll"><span class="linenos"> 6</span>    <span class="k">for</span> <span class="n">step</span> <span class="ow">in</span> <span class="nb">range</span><span class="p">(</span><span class="bp">self</span><span class="o">.</span><span class="n">planner</span><span class="o">.</span><span class="n">max_steps</span><span class="p">):</span>
# </span><span class="hll"><span class="linenos"> 7</span>        <span class="n">result</span> <span class="o">=</span> <span class="bp">self</span><span class="o">.</span><span class="n">_step</span><span class="p">()</span>
# </span><span class="hll"><span class="linenos"> 8</span>        <span class="k">if</span> <span class="n">result</span> <span class="ow">is</span> <span class="ow">not</span> <span class="kc">None</span><span class="p">:</span>
# </span><span class="hll"><span class="linenos"> 9</span>            <span class="k">return</span> <span class="n">result</span>
# </span><span class="linenos">10</span>
# <span class="linenos">11</span>    <span class="k">return</span> <span class="s2">&quot;Max steps reached without completion.&quot;</span>
# </pre></div>
# </div>
# <div style="flex:1;min-width:500px;position:relative;background:rgba(255,255,255,.03);border-left:1px solid #555;color:#ccc;font-family:system-ui,sans-serif"><div style="position:absolute;top:3.0rem;height:1.5rem;display:flex;align-items:center;font-size:14px;padding-left:16px;padding-right:16px"><span style="position:absolute;left:0;top:0;bottom:0;width:3px;background:#f1c40f;border-radius:2px"></span><span style="color:#ddd;line-height:1.4">The initial task is immediately added to memory as a user message so that the Agent can reference it during the loop.</span></div><div style="position:absolu

# %% [markdown]
# Next, the `_step` is where much of the processing happens and now shows an interesting structure:

# %%
from illustrated_agents.chapters.ch6a import tinyagent_step_annotated; tinyagent_step_annotated
# Out:
# <style>
# pre { line-height: 125%; }
# td.linenos .normal { color: #6e7681; background-color: #0d1117; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #6e7681; background-color: #0d1117; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #e6edf3; background-color: #6e7681; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #e6edf3; background-color: #6e7681; padding-left: 5px; padding-right: 5px; }
# .ca .hll { background-color: #6e7681 }
# .ca { background: #0d1117; color: #E6EDF3 }
# .ca .c { color: #8B949E; font-style: italic } /* Comment */
# .ca .err { color: #F85149 } /* Error */
# .ca .esc { color: #E6EDF3 } /* Escape */
# .ca .g { color: #E6EDF3 } /* Generic */
# .ca .k { color: #FF7B72 } /* Keyword */
# .ca .l { color: #A5D6FF } /* Literal */
# .ca .n { color: #E6EDF3 } /* Name */
# .ca .o { color: #FF7B72; font-weight: bold } /* Operator */
# .ca .x { color: #E6EDF3 } /* Other */
# .ca .p { color: #E6EDF3 } /* Punctuation */
# .ca .ch { color: #8B949E; font-style: italic } /* Comment.Hashbang */
# .ca .cm { color: #8B949E; font-style: italic } /* Comment.Multiline */
# .ca .cp { color: #8B949E; font-weight: bold; font-style: italic } /* Comment.Preproc */
# .ca .cpf { color: #8B949E; font-style: italic } /* Comment.PreprocFile */
# .ca .c1 { color: #8B949E; font-style: italic } /* Comment.Single */
# .ca .cs { color: #8B949E; font-weight: bold; font-style: italic } /* Comment.Special */
# .ca .gd { color: #FFA198; background-color: #490202 } /* Generic.Deleted */
# .ca .ge { color: #E6EDF3; font-style: italic } /* Generic.Emph */
# .ca .ges { color: #E6EDF3; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .ca .gr { color: #FFA198 } /* Generic.Error */
# .ca .gh { color: #79C0FF; font-weight: bold } /* Generic.Heading */
# .ca .gi { color: #56D364; background-color: #0F5323 } /* Generic.Inserted */
# .ca .go { color: #8B949E } /* Generic.Output */
# .ca .gp { color: #8B949E } /* Generic.Prompt */
# .ca .gs { color: #E6EDF3; font-weight: bold } /* Generic.Strong */
# .ca .gu { color: #79C0FF } /* Generic.Subheading */
# .ca .gt { color: #FF7B72 } /* Generic.Traceback */
# .ca .g-Underline { color: #E6EDF3; text-decoration: underline } /* Generic.Underline */
# .ca .kc { color: #79C0FF } /* Keyword.Constant */
# .ca .kd { color: #FF7B72 } /* Keyword.Declaration */
# .ca .kn { color: #FF7B72 } /* Keyword.Namespace */
# .ca .kp { color: #79C0FF } /* Keyword.Pseudo */
# .ca .kr { color: #FF7B72 } /* Keyword.Reserved */
# .ca .kt { color: #FF7B72 } /* Keyword.Type */
# .ca .ld { color: #79C0FF } /* Literal.Date */
# .ca .m { color: #A5D6FF } /* Literal.Number */
# .ca .s { color: #A5D6FF } /* Literal.String */
# .ca .na { color: #E6EDF3 } /* Name.Attribute */
# .ca .nb { color: #E6EDF3 } /* Name.Builtin */
# .ca .nc { color: #F0883E; font-weight: bold } /* Name.Class */
# .ca .no { color: #79C0FF; font-weight: bold } /* Name.Constant */
# .ca .nd { color: #D2A8FF; font-weight: bold } /* Name.Decorator */
# .ca .ni { color: #FFA657 } /* Name.Entity */
# .ca .ne { color: #F0883E; font-weight: bold } /* Name.Exception */
# .ca .nf { color: #D2A8FF; font-weight: bold } /* Name.Function */
# .ca .nl { color: #79C0FF; font-weight: bold } /* Name.Label */
# .ca .nn { color: #FF7B72 } /* Name.Namespace */
# .ca .nx { color: #E6EDF3 } /* Name.Other */
# .ca .py { color: #79C0FF } /* Name.Property */
# .ca .nt { color: #7EE787 } /* Name.Tag */
# .ca .nv { color: #79C0FF } /* Name.Variable */
# .ca .ow { color: #FF7B72; font-weight: bold } /* Operator.Word */
# .ca .pm { color: #E6EDF3 } /* Punctuation.Marker */
# .ca .w { color: #6E7681 } /* Text.Whitespace */
# .ca .mb { color: #A5D6FF } /* Literal.Number.Bin */
# .ca .mf { color: #A5D6FF } /* Literal.Number.Float */
# .ca .mh { color: #A5D6FF } /* Literal.Number.Hex */
# .ca .mi { color: #A5D6FF } /* Literal.Number.Integer */
# .ca .mo { color: #A5D6FF } /* Literal.Number.Oct */
# .ca .sa { color: #79C0FF } /* Literal.String.Affix */
# .ca .sb { color: #A5D6FF } /* Literal.String.Backtick */
# .ca .sc { color: #A5D6FF } /* Literal.String.Char */
# .ca .dl { color: #79C0FF } /* Literal.String.Delimiter */
# .ca .sd { color: #A5D6FF } /* Literal.String.Doc */
# .ca .s2 { color: #A5D6FF } /* Literal.String.Double */
# .ca .se { color: #79C0FF } /* Literal.String.Escape */
# .ca .sh { color: #79C0FF } /* Literal.String.Heredoc */
# .ca .si { color: #A5D6FF } /* Literal.String.Interpol */
# .ca .sx { color: #A5D6FF } /* Literal.String.Other */
# .ca .sr { color: #79C0FF } /* Literal.String.Regex */
# .ca .s1 { color: #A5D6FF } /* Literal.String.Single */
# .ca .ss { color: #A5D6FF } /* Literal.String.Symbol */
# .ca .bp { color: #E6EDF3 } /* Name.Builtin.Pseudo */
# .ca .fm { color: #D2A8FF; font-weight: bold } /* Name.Function.Magic */
# .ca .vc { color: #79C0FF } /* Name.Variable.Class */
# .ca .vg { color: #79C0FF } /* Name.Variable.Global */
# .ca .vi { color: #79C0FF } /* Name.Variable.Instance */
# .ca .vm { color: #79C0FF } /* Name.Variable.Magic */
# .ca .il { color: #A5D6FF } /* Literal.Number.Integer.Long */
# .ca pre{margin:0;line-height:1.5rem}
# .ca .hll{background:#3d4626!important;display:block;width:100%}
# .ca .linenos{background:transparent!important}
# </style>
# <div style="display:inline-flex;background:#0d1117;border-radius:8px;border:1px solid #444;margin:10px 0;font-family:monospace">
# <div style="flex:3;overflow-x:auto"><div class="ca"><pre><span></span><span class="linenos"> 1</span><span class="k">def</span><span class="w"> </span><span class="nf">_step</span><span class="p">(</span><span class="bp">self</span><span class="p">)</span> <span class="o">-&gt;</span> <span class="nb">str</span> <span class="o">|</span> <span class="kc">None</span><span class="p">:</span>
# <span class="linenos"> 2</span><span class="w">    </span><span class="sd">&quot;&quot;&quot;Perform a single step of the ReAct loop.&quot;&quot;&quot;</span>
# <span class="linenos"> 3</span>    <span class="c1"># Generate response</span>
# <span class="hll"><span class="linenos"> 4</span>    <span class="n">output</span> <span class="o">=</span> <span class="bp">self</span><span class="o">.</span><span class="n">llm</span><span class="o">.</span><span class="n">generate</span><span class="p">(</span><span class="bp">self</span><span class="o">.</span><span class="n">memory</span><span class="o">.</span><span class="n">get_messages</span><span class="p">())</span>
# </span><span class="hll"><span class="linenos"> 5</span>    <span class="bp">self</span><span class="o">.</span><span class="n">memory</span><span class="o">.</span><span class="n">add</span><span class="p">(</span><span class="s2">&quot;assistant&quot;</span><span class="p">,</span> <span class="n">output</span><span class="p">)</span>
# </span><span class="linenos"> 6</span>
# <span class="linenos"> 7</span>    <span class="c1"># Parse ReAct response (THOUGHT + ACTION)</span>
# <span class="hll"><span class="linenos"> 8</span>    <span class="n">parsed</span> <span class="o">=</span> <span class="bp">self</span><span class="o">.</span><span class="n">planner</span><span class="o">.</span><span class="n">parse_react</span><span class="p">(</span><span class="n">output</span><span class="p">)</span>
# </span><span class="linenos"> 9</span>
# <span class="linenos">10</span>    <span class="c1"># Execute action if present</span>
# <span class="hll"><span class="linenos">11</span>    <span class="k">if</span> <span class="bp">self</span><span class="o">.</span><span class="n">tools</span><span class="o">.</span><span class="n">is_tool_call</span><span class="p">(</span><span class="n">parsed</span><span class="p">[</span><span class="s2">&quot;ACTION&quot;</span><span class="p">]):</span>
# </span><span class="hll"><span class="linenos">12</span>        <span class="k">return</span> <span class="bp">self</span><span class="o">.</span><span class="n">_execute_action</span><span class="p">(</span><span class="n">parsed</span><span class="p">[</span><span class="s2">&quot;ACTION&quot;</span><span class="p">])</span>
# </span><span class="linenos">13</span>
# <span class="linenos">14</spa

# %% [markdown]
# Finally, the `_execute_action` processes the **ACTION** step:

# %%
from illustrated_agents.chapters.ch6a import tinyagent_action_annotated; tinyagent_action_annotated
# Out:
# <style>
# pre { line-height: 125%; }
# td.linenos .normal { color: #6e7681; background-color: #0d1117; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #6e7681; background-color: #0d1117; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #e6edf3; background-color: #6e7681; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #e6edf3; background-color: #6e7681; padding-left: 5px; padding-right: 5px; }
# .ca .hll { background-color: #6e7681 }
# .ca { background: #0d1117; color: #E6EDF3 }
# .ca .c { color: #8B949E; font-style: italic } /* Comment */
# .ca .err { color: #F85149 } /* Error */
# .ca .esc { color: #E6EDF3 } /* Escape */
# .ca .g { color: #E6EDF3 } /* Generic */
# .ca .k { color: #FF7B72 } /* Keyword */
# .ca .l { color: #A5D6FF } /* Literal */
# .ca .n { color: #E6EDF3 } /* Name */
# .ca .o { color: #FF7B72; font-weight: bold } /* Operator */
# .ca .x { color: #E6EDF3 } /* Other */
# .ca .p { color: #E6EDF3 } /* Punctuation */
# .ca .ch { color: #8B949E; font-style: italic } /* Comment.Hashbang */
# .ca .cm { color: #8B949E; font-style: italic } /* Comment.Multiline */
# .ca .cp { color: #8B949E; font-weight: bold; font-style: italic } /* Comment.Preproc */
# .ca .cpf { color: #8B949E; font-style: italic } /* Comment.PreprocFile */
# .ca .c1 { color: #8B949E; font-style: italic } /* Comment.Single */
# .ca .cs { color: #8B949E; font-weight: bold; font-style: italic } /* Comment.Special */
# .ca .gd { color: #FFA198; background-color: #490202 } /* Generic.Deleted */
# .ca .ge { color: #E6EDF3; font-style: italic } /* Generic.Emph */
# .ca .ges { color: #E6EDF3; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .ca .gr { color: #FFA198 } /* Generic.Error */
# .ca .gh { color: #79C0FF; font-weight: bold } /* Generic.Heading */
# .ca .gi { color: #56D364; background-color: #0F5323 } /* Generic.Inserted */
# .ca .go { color: #8B949E } /* Generic.Output */
# .ca .gp { color: #8B949E } /* Generic.Prompt */
# .ca .gs { color: #E6EDF3; font-weight: bold } /* Generic.Strong */
# .ca .gu { color: #79C0FF } /* Generic.Subheading */
# .ca .gt { color: #FF7B72 } /* Generic.Traceback */
# .ca .g-Underline { color: #E6EDF3; text-decoration: underline } /* Generic.Underline */
# .ca .kc { color: #79C0FF } /* Keyword.Constant */
# .ca .kd { color: #FF7B72 } /* Keyword.Declaration */
# .ca .kn { color: #FF7B72 } /* Keyword.Namespace */
# .ca .kp { color: #79C0FF } /* Keyword.Pseudo */
# .ca .kr { color: #FF7B72 } /* Keyword.Reserved */
# .ca .kt { color: #FF7B72 } /* Keyword.Type */
# .ca .ld { color: #79C0FF } /* Literal.Date */
# .ca .m { color: #A5D6FF } /* Literal.Number */
# .ca .s { color: #A5D6FF } /* Literal.String */
# .ca .na { color: #E6EDF3 } /* Name.Attribute */
# .ca .nb { color: #E6EDF3 } /* Name.Builtin */
# .ca .nc { color: #F0883E; font-weight: bold } /* Name.Class */
# .ca .no { color: #79C0FF; font-weight: bold } /* Name.Constant */
# .ca .nd { color: #D2A8FF; font-weight: bold } /* Name.Decorator */
# .ca .ni { color: #FFA657 } /* Name.Entity */
# .ca .ne { color: #F0883E; font-weight: bold } /* Name.Exception */
# .ca .nf { color: #D2A8FF; font-weight: bold } /* Name.Function */
# .ca .nl { color: #79C0FF; font-weight: bold } /* Name.Label */
# .ca .nn { color: #FF7B72 } /* Name.Namespace */
# .ca .nx { color: #E6EDF3 } /* Name.Other */
# .ca .py { color: #79C0FF } /* Name.Property */
# .ca .nt { color: #7EE787 } /* Name.Tag */
# .ca .nv { color: #79C0FF } /* Name.Variable */
# .ca .ow { color: #FF7B72; font-weight: bold } /* Operator.Word */
# .ca .pm { color: #E6EDF3 } /* Punctuation.Marker */
# .ca .w { color: #6E7681 } /* Text.Whitespace */
# .ca .mb { color: #A5D6FF } /* Literal.Number.Bin */
# .ca .mf { color: #A5D6FF } /* Literal.Number.Float */
# .ca .mh { color: #A5D6FF } /* Literal.Number.Hex */
# .ca .mi { color: #A5D6FF } /* Literal.Number.Integer */
# .ca .mo { color: #A5D6FF } /* Literal.Number.Oct */
# .ca .sa { color: #79C0FF } /* Literal.String.Affix */
# .ca .sb { color: #A5D6FF } /* Literal.String.Backtick */
# .ca .sc { color: #A5D6FF } /* Literal.String.Char */
# .ca .dl { color: #79C0FF } /* Literal.String.Delimiter */
# .ca .sd { color: #A5D6FF } /* Literal.String.Doc */
# .ca .s2 { color: #A5D6FF } /* Literal.String.Double */
# .ca .se { color: #79C0FF } /* Literal.String.Escape */
# .ca .sh { color: #79C0FF } /* Literal.String.Heredoc */
# .ca .si { color: #A5D6FF } /* Literal.String.Interpol */
# .ca .sx { color: #A5D6FF } /* Literal.String.Other */
# .ca .sr { color: #79C0FF } /* Literal.String.Regex */
# .ca .s1 { color: #A5D6FF } /* Literal.String.Single */
# .ca .ss { color: #A5D6FF } /* Literal.String.Symbol */
# .ca .bp { color: #E6EDF3 } /* Name.Builtin.Pseudo */
# .ca .fm { color: #D2A8FF; font-weight: bold } /* Name.Function.Magic */
# .ca .vc { color: #79C0FF } /* Name.Variable.Class */
# .ca .vg { color: #79C0FF } /* Name.Variable.Global */
# .ca .vi { color: #79C0FF } /* Name.Variable.Instance */
# .ca .vm { color: #79C0FF } /* Name.Variable.Magic */
# .ca .il { color: #A5D6FF } /* Literal.Number.Integer.Long */
# .ca pre{margin:0;line-height:1.5rem}
# .ca .hll{background:#3d4626!important;display:block;width:100%}
# .ca .linenos{background:transparent!important}
# </style>
# <div style="display:inline-flex;background:#0d1117;border-radius:8px;border:1px solid #444;margin:10px 0;font-family:monospace">
# <div style="flex:3;overflow-x:auto"><div class="ca"><pre><span></span><span class="linenos"> 1</span><span class="k">def</span><span class="w"> </span><span class="nf">_execute_action</span><span class="p">(</span><span class="bp">self</span><span class="p">,</span> <span class="n">action</span><span class="p">:</span> <span class="nb">str</span><span class="p">)</span> <span class="o">-&gt;</span> <span class="nb">str</span> <span class="o">|</span> <span class="kc">None</span><span class="p">:</span>
# <span class="linenos"> 2</span><span class="w">    </span><span class="sd">&quot;&quot;&quot;Execute a tool action.&quot;&quot;&quot;</span>
# <span class="hll"><span class="linenos"> 3</span>    <span class="n">tool_call</span> <span class="o">=</span> <span class="bp">self</span><span class="o">.</span><span class="n">tools</span><span class="o">.</span><span class="n">parse_tool_call</span><span class="p">(</span><span class="n">action</span><span class="p">)</span>
# </span><span class="linenos"> 4</span>
# <span class="linenos"> 5</span>    <span class="c1"># Final answer ends the loop</span>
# <span class="hll"><span class="linenos"> 6</span>    <span class="k">if</span> <span class="n">tool_call</span><span class="p">[</span><span class="s2">&quot;tool&quot;</span><span class="p">]</span> <span class="o">==</span> <span class="s2">&quot;final_answer&quot;</span><span class="p">:</span>
# </span><span class="hll"><span class="linenos"> 7</span>        <span class="k">return</span> <span class="n">tool_call</span><span class="o">.</span><span class="n">get</span><span class="p">(</span><span class="s2">&quot;args&quot;</span><span class="p">,</span> <span class="s2">&quot;&quot;</span><span class="p">)</span>
# </span><span class="linenos"> 8</span>
# <span class="linenos"> 9</span>    <span class="c1"># Execute tool and add observation to memory</span>
# <span class="hll"><span class="linenos">10</span>    <span class="n">observation</span> <span class="o">=</span> <span class="bp">self</span><span class="o">.</span><span class="n">tools</span><span class="o">.</span><span class="n">run_tool</span><span class="p">(</span><span class="n">tool_call</span><span class="p">)</span>
# </span><span class="hll"><span class="linenos">11</span>    <span class="n">obs_prompt</span> <span class="o">=</span> <span class="bp">self</span><span class="o">.</span><span class="n">planner</span><span class="o">.</span><span class="n">format_observation</span><span class="p">(</span><span class="n">action</span><span class="p">,</span> <span class="n">observation</span><span class="p">)</span>
# </span><span class="hll"><span class="linenos">12</span>    <span class="bp">self</span><span class="o">.</span><span class="n">memory</span><span

# %% [markdown]
# If you want, you can also run the diff below but be warned that it is much bigger than last few chapters!

# %%
# from illustrated_agents.chapters.ch6 import tinyagents_diff; tinyagents_diff

# %% [markdown]
# Now that we went through all steps, let's start creating your ReAct-based `TinyAgent` and explore whether it can actually do things autonomously!

# %%
# Define tools
def calculator(a: str, b: str) -> float:
    return float(a) + float(b)

def get_weather(location: str) -> str:
    return f"Weather in {location}: Sunny, 72°F"

# Register tools
tools = Tools()
tools.add_tool("calculator", calculator, "Adds two numbers: calculator(a, b)")
tools.add_tool("get_weather", get_weather, "Gets weather: get_weather(city)")

# Memory
memory = Memory()

# ReAct
react = ReAct(max_steps=10)

# Create agent
agent = TinyAgent(llm=llm, tools=tools, memory=memory, planner=react)

# %%
# Multi-step task with reasoning
agent.run("""
I'm planning a trip! Help me with these tasks:
1. What's the weather in New York City?
2. What's the weather in Los Angeles?
3. I saved $150.50 and my friend is giving me $75.25. How much do I have for the trip?

Based on the weather, which city would you recommend I visit?
""")
# Out:
# 'The weather is the same (sunny, 72°F) in both New York City and Los Angeles. With $225.75, you could visit either city, as the cost of travel and activities would likely be similar.'

# %% [markdown]
# Amazing! If you used **Gemma 3: 12B** then it should have run correctly. It performed all tasks in sequence and gave us back the final reply. Let's explore how many steps it took:

# %%
messages = agent.memory.get_messages()
nr_api_calls = sum(1 for msg in messages if "ACTION:" in msg["content"] and '"tool":' in msg["content"] and '"final_answer"' not in msg["content"])
nr_assistant_msgs = sum(1 for msg in messages if msg["role"] == "assistant")

print(f"It took {nr_api_calls} Tool calls and {nr_assistant_msgs} assistant messages!\n\n===== Messages: ====="); messages
# Out:
# It took 3 Tool calls and 4 assistant messages!
#
# ===== Messages: =====
# [{'role': 'user',
#   'content': 'You are a helpful AI agent.\n\n\n# ReACT (Reason and Act)\n\nYou are a ReAct agent that performs exactly ONE step per turn.\nMake sure to break down a given task into smaller steps and decide whether to use a tool or provide a final answer.\n\n## ReACT Format\n\nYou use the following format for each step:\n\nTHOUGHT: [Your reasoning about what to do next]\nACTION:\n{\n    "tool": "a_tool_name",\n    "args": [...],\n}\n\nIf no tool is needed and you want to provide an intermediate answer, use:\n\nACTION:\n{\n    "tool": "intermediate_answer",\n    "args": "insert your intermediate answer here"\n}\n\nAn observation will be provided after each action. You do not generate the observation yourself.\n\n## ReACT Completion\n\nTo provide the final answer to the task, use an action blob with "tool": "final_answer" tool. \nIt is the only way to complete the task, else you will be stuck on a loop. So your final output should look like this:\n\nACTION:\n{\n    "tool": "final_answer",\n    "args": "insert your final answer here"\n}\n\nOnly use the final_answer tool when you are completely done with all subtasks and have the final answer ready.\n\n\n\n# Tools\n\nIf needed, you can only use the following tools to assist you in completing tasks:\n\n`calculator`: Adds two numbers: calculator(a, b)\n`get_weather`: Gets weather: get_weather(city)\n\nTo use a tool, respond with JSON: {"tool": "name", "args": [...]}\n'},
#  {'role': 'user',
#   'content': "\nI'm planning a trip! Help me with these tasks:\n1. What's the weather in New York City?\n2. What's the weather in Los Angeles?\n3. I saved $150.50 and my friend is giving me $75.25. How much do I have for the trip?\n\nBased on the weather, which city would you recommend I visit?\n"},
#  {'role': 'assistant',
#   'content': 'THOUGHT: Okay, I need to get the weather for New York City and Los Angeles, and then calculate the total amount of money I have for the trip. Finally, I\'ll recommend a city based on the weather. I\'ll start by getting the weather for New York City.\nACTION:\n{\n    "tool": "get_weather",\n    "args": ["New York City"]\n}\n'},
#  {'role': 'user',
#   'content': 'OBSERVATION: {\n    "tool": "get_weather",\n    "args": ["New York City"]\n} -> Weather in New York City: Sunny, 72°F'},
#  {'role': 'assistant',
#   'content': 'THOUGHT: Now that I have the weather for New York City, I need to get the weather for Los Angeles.\nACTION:\n{\n    "tool": "get_weather",\n    "args": ["Los Angeles"]\n}'},
#  {'role': 'user',
#   'content': 'OBSERVATION: {\n    "tool": "get_weather",\n    "args": ["Los Angeles"]\n} -> Weather in Los Angeles: Sunny, 72°F'},
#  {'role': 'assistant',
#   'content': '### Assistant:\nTHOUGHT: I have the weather for both cities. Now I need to calculate the total amount of money I have.\nACTION:\n{\n    "tool": "calculator",\n    "args": [150.50, 75.25]\n}'},
#  {'role': 'user',
#   'content': 'OBSERVATION: {\n    "tool": "calculator",\n    "args": [150.50, 75.25]\n} -> 225.75'},
#  {'role': 'assistant',
#   'content': '### Assistant:\nTHOUGHT: I now have the total amount of money I have for the trip. New York City is sunny and 72°F, and Los Angeles is also sunny and 72°F. Since the weather is the same in both cities, the amount of money I have will be the deciding factor. I have $225.75. I\'m ready to make a recommendation.\nACTION:\n{\n    "tool": "final_answer",\n    "args": "The weather is the same (sunny, 72°F) in both New York City and Los Angeles. With $225.75, you could visit either city, as the cost of travel and activities would likely be similar."\n}'}]

# %% [markdown]
# In our example, 3 tools were called, namely the `get_weather` tool twice and the `calculator` once. Both without any problems. Then, your `TinyAgent` created a final message to summarize the results.
