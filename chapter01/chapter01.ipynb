# %% [markdown]
# <h1>Chapter 1 - Introducing Agents</h1>
# <i>Exploring AI Agents</i>
#
#
# <a href="..."><img src="https://img.shields.io/badge/Buy%20the%20Book!-grey?logo=amazon"></a>
# <a href="..."><img src="https://img.shields.io/badge/O'Reilly-white.svg?logo=..."></a>
# <a href="..."><img src="https://img.shields.io/badge/GitHub%20Repository-black?logo=github"></a>
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](...)
#
# ---
#
# This notebook is for Chapter 1 of the [An Illustrated Guide to AI Agents](...) book by [Maarten Grootendorst](https://www.linkedin.com/in/mgrootendorst/) and [Jay Alammar](https://www.linkedin.com/in/jalammar).
#
# ---
#
# <a href="...">
# <img src="https://learning.oreilly.com/covers/urn:orm:book:9798341662681/400w/" width="350"/></a>

# %% [markdown]
# ### [OPTIONAL] - Installing Packages on <img src="https://colab.google/static/images/icons/colab.png" width=100>
#
# If you are viewing this notebook on Google Colab (or any other cloud vendor), you need to **uncomment and run** the following codeblock to install the dependencies for this chapter:

# %% [markdown]
# ---
#
# 💡 **NOTE**: We will want to use a GPU to run the examples in this notebook. In Google Colab, go to
# **Runtime > Change runtime type > Hardware accelerator > GPU > GPU type > T4**.
#
# ---

# %%
# %%capture
# !pip install illustrated-agents

# %% [markdown]
# # Building an `Agent` from Scratch
#
# Throughout this book, we will explore various components of Agent, which together make up the `TinyAgent` which is given in the `\tinyagent` folder.
# This code builds an Agent (called `TinyAgent`) entirely from scratch, using only API calls to the LLM.
#
# To do so, we make use of a highly modular and educational structure of our `TinyAgent` that focuses on understanding the vital components of an Agent.
# As such, we start this chapter with an `agent.py` and slowly build it up by adding components:
#
# ![../images/overview.png](../images/overview.png)
#
# Each chapter builds on the previous one, starting with this one which creates the `agent.py` file. In each chapter, we add a module to the `agent.py` framework so that we can improve its behavior. We will be iteratively updating `agent.py` to implement this behavior:
#
# | Chapter | Module Added | Capability |
# |---------|--------------|------------|
# | 1 | (skeleton) | Basic structure with placeholders |
# | 2 & 3 | `llm.py` | Can query an LLM (stateless) |
# | 4 | `memory.py` | Remembers conversation history |
# | 5 | `tools.py` | Can call tools (single-shot) |
# | 6 | `planning.py` and `reflection.py` | ReAct loop (multi-step reasoning) |
# | 8 | `coordinator.py` | Multi-agent collaboration |

# %% [markdown]
# # The `TinyAgent`
#
# Let's start with building our `TinyAgent`. This class will start with the LLM we defined above and nothing more. It technically cannot be considered an Agent yet until we have added all above components.
#
# ![../images/ch1.png](../images/ch1.png)
#
# That said, let's build the scaffolding of this `TinyAgent`. There are several components that we can already define without using any LLM, namely:
#
# * Attributes that we add later on
# * `run` which is the main function to run the Agent
# * `_step` which is a single step of the Agent (it may run for multiple steps)

# %%
class TinyAgent:
    """A minimal, modular, and educational agent framework."""

    def __init__(self):
        self.llm = None      # Chapter 2 & 3: Add LLM
        self.memory = None   # Chapter 4: Add Memory
        self.tools = None    # Chapter 5: Add Tools
        self.planner = None  # Chapter 6: Add Planning
        self.reflector = None  # Chapter 6: Add Reflection

    def run(self, task: str) -> str:
        """Run the Agent on a task."""
        return self._step(task)

    def _step(self, task: str) -> str:
        """Perform a single step."""
        # Placeholder - will be implemented in later chapters
        return f"Received: {task}"

# %% [markdown]
# Looking a little bit closer at each function gives us more clarity with respect to the difference between the `run` and a single `_step`:

# %%
from illustrated_agents.chapters.ch1 import agent_annotated; agent_annotated
# Out:
# <style>
# pre { line-height: 125%; }
# td.linenos .normal { color: #6e7681; background-color: #0d1117; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #6e7681; background-color: #0d1117; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #e6edf3; background-color: #6e7681; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #e6edf3; background-color: #6e7681; padding-left: 5px; padding-right: 5px; }
# .ca-ef8b70f0 .hll { background-color: #6e7681 }
# .ca-ef8b70f0 { background: #0d1117; color: #E6EDF3 }
# .ca-ef8b70f0 .c { color: #8B949E; font-style: italic } /* Comment */
# .ca-ef8b70f0 .err { color: #F85149 } /* Error */
# .ca-ef8b70f0 .esc { color: #E6EDF3 } /* Escape */
# .ca-ef8b70f0 .g { color: #E6EDF3 } /* Generic */
# .ca-ef8b70f0 .k { color: #FF7B72 } /* Keyword */
# .ca-ef8b70f0 .l { color: #A5D6FF } /* Literal */
# .ca-ef8b70f0 .n { color: #E6EDF3 } /* Name */
# .ca-ef8b70f0 .o { color: #FF7B72; font-weight: bold } /* Operator */
# .ca-ef8b70f0 .x { color: #E6EDF3 } /* Other */
# .ca-ef8b70f0 .p { color: #E6EDF3 } /* Punctuation */
# .ca-ef8b70f0 .ch { color: #8B949E; font-style: italic } /* Comment.Hashbang */
# .ca-ef8b70f0 .cm { color: #8B949E; font-style: italic } /* Comment.Multiline */
# .ca-ef8b70f0 .cp { color: #8B949E; font-weight: bold; font-style: italic } /* Comment.Preproc */
# .ca-ef8b70f0 .cpf { color: #8B949E; font-style: italic } /* Comment.PreprocFile */
# .ca-ef8b70f0 .c1 { color: #8B949E; font-style: italic } /* Comment.Single */
# .ca-ef8b70f0 .cs { color: #8B949E; font-weight: bold; font-style: italic } /* Comment.Special */
# .ca-ef8b70f0 .gd { color: #FFA198; background-color: #490202 } /* Generic.Deleted */
# .ca-ef8b70f0 .ge { color: #E6EDF3; font-style: italic } /* Generic.Emph */
# .ca-ef8b70f0 .ges { color: #E6EDF3; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .ca-ef8b70f0 .gr { color: #FFA198 } /* Generic.Error */
# .ca-ef8b70f0 .gh { color: #79C0FF; font-weight: bold } /* Generic.Heading */
# .ca-ef8b70f0 .gi { color: #56D364; background-color: #0F5323 } /* Generic.Inserted */
# .ca-ef8b70f0 .go { color: #8B949E } /* Generic.Output */
# .ca-ef8b70f0 .gp { color: #8B949E } /* Generic.Prompt */
# .ca-ef8b70f0 .gs { color: #E6EDF3; font-weight: bold } /* Generic.Strong */
# .ca-ef8b70f0 .gu { color: #79C0FF } /* Generic.Subheading */
# .ca-ef8b70f0 .gt { color: #FF7B72 } /* Generic.Traceback */
# .ca-ef8b70f0 .g-Underline { color: #E6EDF3; text-decoration: underline } /* Generic.Underline */
# .ca-ef8b70f0 .kc { color: #79C0FF } /* Keyword.Constant */
# .ca-ef8b70f0 .kd { color: #FF7B72 } /* Keyword.Declaration */
# .ca-ef8b70f0 .kn { color: #FF7B72 } /* Keyword.Namespace */
# .ca-ef8b70f0 .kp { color: #79C0FF } /* Keyword.Pseudo */
# .ca-ef8b70f0 .kr { color: #FF7B72 } /* Keyword.Reserved */
# .ca-ef8b70f0 .kt { color: #FF7B72 } /* Keyword.Type */
# .ca-ef8b70f0 .ld { color: #79C0FF } /* Literal.Date */
# .ca-ef8b70f0 .m { color: #A5D6FF } /* Literal.Number */
# .ca-ef8b70f0 .s { color: #A5D6FF } /* Literal.String */
# .ca-ef8b70f0 .na { color: #E6EDF3 } /* Name.Attribute */
# .ca-ef8b70f0 .nb { color: #E6EDF3 } /* Name.Builtin */
# .ca-ef8b70f0 .nc { color: #F0883E; font-weight: bold } /* Name.Class */
# .ca-ef8b70f0 .no { color: #79C0FF; font-weight: bold } /* Name.Constant */
# .ca-ef8b70f0 .nd { color: #D2A8FF; font-weight: bold } /* Name.Decorator */
# .ca-ef8b70f0 .ni { color: #FFA657 } /* Name.Entity */
# .ca-ef8b70f0 .ne { color: #F0883E; font-weight: bold } /* Name.Exception */
# .ca-ef8b70f0 .nf { color: #D2A8FF; font-weight: bold } /* Name.Function */
# .ca-ef8b70f0 .nl { color: #79C0FF; font-weight: bold } /* Name.Label */
# .ca-ef8b70f0 .nn { color: #FF7B72 } /* Name.Namespace */
# .ca-ef8b70f0 .nx { color: #E6EDF3 } /* Name.Other */
# .ca-ef8b70f0 .py { color: #79C0FF } /* Name.Property */
# .ca-ef8b70f0 .nt { color: #7EE787 } /* Name.Tag */
# .ca-ef8b70f0 .nv { color: #79C0FF } /* Name.Variable */
# .ca-ef8b70f0 .ow { color: #FF7B72; font-weight: bold } /* Operator.Word */
# .ca-ef8b70f0 .pm { color: #E6EDF3 } /* Punctuation.Marker */
# .ca-ef8b70f0 .w { color: #6E7681 } /* Text.Whitespace */
# .ca-ef8b70f0 .mb { color: #A5D6FF } /* Literal.Number.Bin */
# .ca-ef8b70f0 .mf { color: #A5D6FF } /* Literal.Number.Float */
# .ca-ef8b70f0 .mh { color: #A5D6FF } /* Literal.Number.Hex */
# .ca-ef8b70f0 .mi { color: #A5D6FF } /* Literal.Number.Integer */
# .ca-ef8b70f0 .mo { color: #A5D6FF } /* Literal.Number.Oct */
# .ca-ef8b70f0 .sa { color: #79C0FF } /* Literal.String.Affix */
# .ca-ef8b70f0 .sb { color: #A5D6FF } /* Literal.String.Backtick */
# .ca-ef8b70f0 .sc { color: #A5D6FF } /* Literal.String.Char */
# .ca-ef8b70f0 .dl { color: #79C0FF } /* Literal.String.Delimiter */
# .ca-ef8b70f0 .sd { color: #A5D6FF } /* Literal.String.Doc */
# .ca-ef8b70f0 .s2 { color: #A5D6FF } /* Literal.String.Double */
# .ca-ef8b70f0 .se { color: #79C0FF } /* Literal.String.Escape */
# .ca-ef8b70f0 .sh { color: #79C0FF } /* Literal.String.Heredoc */
# .ca-ef8b70f0 .si { color: #A5D6FF } /* Literal.String.Interpol */
# .ca-ef8b70f0 .sx { color: #A5D6FF } /* Literal.String.Other */
# .ca-ef8b70f0 .sr { color: #79C0FF } /* Literal.String.Regex */
# .ca-ef8b70f0 .s1 { color: #A5D6FF } /* Literal.String.Single */
# .ca-ef8b70f0 .ss { color: #A5D6FF } /* Literal.String.Symbol */
# .ca-ef8b70f0 .bp { color: #E6EDF3 } /* Name.Builtin.Pseudo */
# .ca-ef8b70f0 .fm { color: #D2A8FF; font-weight: bold } /* Name.Function.Magic */
# .ca-ef8b70f0 .vc { color: #79C0FF } /* Name.Variable.Class */
# .ca-ef8b70f0 .vg { color: #79C0FF } /* Name.Variable.Global */
# .ca-ef8b70f0 .vi { color: #79C0FF } /* Name.Variable.Instance */
# .ca-ef8b70f0 .vm { color: #79C0FF } /* Name.Variable.Magic */
# .ca-ef8b70f0 .il { color: #A5D6FF } /* Literal.Number.Integer.Long */
# .ca-ef8b70f0 pre{margin:0;line-height:1.5em}
# .ca-ef8b70f0 .hll{background:#3d4626!important;display:block;width:100%}
# .ca-ef8b70f0 .linenos{background:transparent!important}
# </style>
# <div style="display:inline-flex;background:#0d1117;border-radius:8px;border:1px solid #444;margin:10px 0;font-family:monospace">
# <div style="flex:3;overflow-x:auto"><div class="ca-ef8b70f0"><pre><span></span><span class="linenos"> 1</span><span class="k">class</span><span class="w"> </span><span class="nc">TinyAgent</span><span class="p">:</span>
# <span class="linenos"> 2</span><span class="w">    </span><span class="sd">&quot;&quot;&quot;A minimal, modular, and educational agent framework.&quot;&quot;&quot;</span>
# <span class="linenos"> 3</span>
# <span class="linenos"> 4</span>    <span class="k">def</span><span class="w"> </span><span class="fm">__init__</span><span class="p">(</span><span class="bp">self</span><span class="p">):</span>
# <span class="linenos"> 5</span>        <span class="bp">self</span><span class="o">.</span><span class="n">llm</span> <span class="o">=</span> <span class="kc">None</span>  <span class="c1"># Chapter 2 &amp; 3: Add LLM</span>
# <span class="linenos"> 6</span>        <span class="bp">self</span><span class="o">.</span><span class="n">memory</span> <span class="o">=</span> <span class="kc">None</span>  <span class="c1"># Chapter 4: Add Memory</span>
# <span class="linenos"> 7</span>        <span class="bp">self</span><span class="o">.</span><span class="n">tools</span> <span class="o">=</span> <span class="kc">None</span>  <span class="c1"># Chapter 5: Add Tools</span>
# <span class="linenos"> 8</span>        <span class="bp">self</span><span class="o">.</span><span class="n">planner</span> <span class="o">=</span> <span class="kc">None</span>  <span class="c1"># Chapter 6: Add Planning</span>
# <span class="linenos"> 9</span>        <span class="bp">self</span><span class="o">.</span><span class="n">reflector</span> <span class="o">=</span> <span class="kc">None</span>  <span class="c1"># Chapter 6: Add Reflection</span>
# <span class="linenos">10</span>
# <span class="hll"><span class="linenos">11</span>    <span class="k">def</span><span class="w"> </span><span class="nf">run</span><span class="p">(</span><span class="bp">self</span><span class="p">,</span> <span class=

# %% [markdown]
# Then, all that is left to do is "run" the Agent, which gives back nothing more than what is has received. After all, without a "brain", there is nothing more than your `TinyAgent` can do:

# %%
agent = TinyAgent()
agent.run("What is 2 + 2?")
# Out:
# 'Received: What is 2 + 2?'

# %% [markdown]
# So... let's continue to the next chapter where we can give it a "brain"!
