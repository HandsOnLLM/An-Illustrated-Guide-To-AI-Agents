# %% [markdown]
# <h1>Chapter 1 - Introducing Agents</h1>
# <i>Exploring AI Agents</i>
#
#
# <a href="..."><img src="https://img.shields.io/badge/Buy%20the%20Book!-grey?logo=amazon"></a>
# <a href="..."><img src="https://img.shields.io/badge/O'Reilly-white.svg?logo=..."></a>
# <a href="..."><img src="https://img.shields.io/badge/GitHub%20Repository-black?logo=github"></a>
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](...)
#
# ---
#
# This notebook is for Chapter 1 of the [An Illustrated Guide to AI Agents](...) book by [Maarten Grootendorst](https://www.linkedin.com/in/mgrootendorst/) and [Jay Alammar](https://www.linkedin.com/in/jalammar).
#
# ---
#
# <a href="...">
# <img src="https://learning.oreilly.com/covers/urn:orm:book:9798341662681/400w/" width="350"/></a>

# %% [markdown]
# ### [OPTIONAL] - Installing Packages on <img src="https://colab.google/static/images/icons/colab.png" width=100>
#
# If you are viewing this notebook on Google Colab (or any other cloud vendor), you need to **uncomment and run** the following codeblock to install the dependencies for this chapter:

# %% [markdown]
# ---
#
# 💡 **NOTE**: We will want to use a GPU to run the examples in this notebook. In Google Colab, go to
# **Runtime > Change runtime type > Hardware accelerator > GPU > GPU type > T4**.
#
# ---

# %%
# %%capture
# !pip install illustrated-agents

# %% [markdown]
# # Building an `Agent` from Scratch
#
# Throughout this book, we will explore various components of Agent, which together make up the `TinyAgent` which is given in the `\tinyagent` folder.
# This code builds an Agent (called `TinyAgent`) entirely from scratch, using only API calls to the LLM.
#
# To do so, we make use of a highly modular and educational structure of our `TinyAgent` that focuses on understanding the vital components of an Agent.
# As such, we start this chapter with an `agent.py` and slowly build it up by adding components:
#
# ![../images/overview.png](../images/overview.png)
#
# Each chapter builds on the previous one, starting with this one which creates the `agent.py` file. In each chapter, we add a module to the `agent.py` framework so that we can improve its behavior. We will be iteratively updating `agent.py` to implement this behavior:
#
# | Chapter | Module Added | Capability |
# |---------|--------------|------------|
# | 1 | (skeleton) | Basic structure with placeholders |
# | 2 & 3 | `llm.py` | Can query an LLM (stateless) |
# | 4 | `memory.py` | Remembers conversation history |
# | 5 | `tools.py` | Can call tools (single-shot) |
# | 6 | `planning.py` and `reflection.py` | ReAct loop (multi-step reasoning) |
# | 8 | `coordinator.py` | Multi-agent collaboration |

# %% [markdown]
# # The `TinyAgent`
#
# Let's start with building our `TinyAgent`. This class will start with the LLM we defined above and nothing more. It technically cannot be considered an Agent yet until we have added all above components.
#
# ![../images/ch1.png](../images/ch1.png)
#
# That said, let's build the scaffolding of this `TinyAgent`. There are several components that we can already define without using any LLM, namely:
#
# * Attributes that we add later on
# * `run` which is the main function to run the Agent
# * `_step` which is a single step of the Agent (it may run for multiple steps)

# %%
class TinyAgent:
    """A minimal, modular, and educational agent framework."""

    def __init__(self):
        self.llm = None      # Chapter 2 & 3: Add LLM
        self.memory = None   # Chapter 4: Add Memory
        self.tools = None    # Chapter 5: Add Tools
        self.planner = None  # Chapter 6: Add Planning
        self.reflector = None  # Chapter 6: Add Reflection

    def run(self, task: str) -> str:
        """Run the Agent on a task."""
        return self._step(task)

    def _step(self, task: str) -> str:
        """Perform a single step."""
        # Placeholder - will be implemented in later chapters
        return f"Received: {task}"

# %% [markdown]
# Looking a little bit closer at each function gives us more clarity with respect to the difference between the `run` and a single `_step`:

# %%
from illustrated_agents.chapters.ch1 import agent_annotated; agent_annotated
# Out:
# <style>
# pre { line-height: 125%; }
# td.linenos .normal { color: #6e7681; background-color: #0d1117; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #6e7681; background-color: #0d1117; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #e6edf3; background-color: #6e7681; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #e6edf3; background-color: #6e7681; padding-left: 5px; padding-right: 5px; }
# .ca .hll { background-color: #6e7681 }
# .ca { background: #0d1117; color: #E6EDF3 }
# .ca .c { color: #8B949E; font-style: italic } /* Comment */
# .ca .err { color: #F85149 } /* Error */
# .ca .esc { color: #E6EDF3 } /* Escape */
# .ca .g { color: #E6EDF3 } /* Generic */
# .ca .k { color: #FF7B72 } /* Keyword */
# .ca .l { color: #A5D6FF } /* Literal */
# .ca .n { color: #E6EDF3 } /* Name */
# .ca .o { color: #FF7B72; font-weight: bold } /* Operator */
# .ca .x { color: #E6EDF3 } /* Other */
# .ca .p { color: #E6EDF3 } /* Punctuation */
# .ca .ch { color: #8B949E; font-style: italic } /* Comment.Hashbang */
# .ca .cm { color: #8B949E; font-style: italic } /* Comment.Multiline */
# .ca .cp { color: #8B949E; font-weight: bold; font-style: italic } /* Comment.Preproc */
# .ca .cpf { color: #8B949E; font-style: italic } /* Comment.PreprocFile */
# .ca .c1 { color: #8B949E; font-style: italic } /* Comment.Single */
# .ca .cs { color: #8B949E; font-weight: bold; font-style: italic } /* Comment.Special */
# .ca .gd { color: #FFA198; background-color: #490202 } /* Generic.Deleted */
# .ca .ge { color: #E6EDF3; font-style: italic } /* Generic.Emph */
# .ca .ges { color: #E6EDF3; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .ca .gr { color: #FFA198 } /* Generic.Error */
# .ca .gh { color: #79C0FF; font-weight: bold } /* Generic.Heading */
# .ca .gi { color: #56D364; background-color: #0F5323 } /* Generic.Inserted */
# .ca .go { color: #8B949E } /* Generic.Output */
# .ca .gp { color: #8B949E } /* Generic.Prompt */
# .ca .gs { color: #E6EDF3; font-weight: bold } /* Generic.Strong */
# .ca .gu { color: #79C0FF } /* Generic.Subheading */
# .ca .gt { color: #FF7B72 } /* Generic.Traceback */
# .ca .g-Underline { color: #E6EDF3; text-decoration: underline } /* Generic.Underline */
# .ca .kc { color: #79C0FF } /* Keyword.Constant */
# .ca .kd { color: #FF7B72 } /* Keyword.Declaration */
# .ca .kn { color: #FF7B72 } /* Keyword.Namespace */
# .ca .kp { color: #79C0FF } /* Keyword.Pseudo */
# .ca .kr { color: #FF7B72 } /* Keyword.Reserved */
# .ca .kt { color: #FF7B72 } /* Keyword.Type */
# .ca .ld { color: #79C0FF } /* Literal.Date */
# .ca .m { color: #A5D6FF } /* Literal.Number */
# .ca .s { color: #A5D6FF } /* Literal.String */
# .ca .na { color: #E6EDF3 } /* Name.Attribute */
# .ca .nb { color: #E6EDF3 } /* Name.Builtin */
# .ca .nc { color: #F0883E; font-weight: bold } /* Name.Class */
# .ca .no { color: #79C0FF; font-weight: bold } /* Name.Constant */
# .ca .nd { color: #D2A8FF; font-weight: bold } /* Name.Decorator */
# .ca .ni { color: #FFA657 } /* Name.Entity */
# .ca .ne { color: #F0883E; font-weight: bold } /* Name.Exception */
# .ca .nf { color: #D2A8FF; font-weight: bold } /* Name.Function */
# .ca .nl { color: #79C0FF; font-weight: bold } /* Name.Label */
# .ca .nn { color: #FF7B72 } /* Name.Namespace */
# .ca .nx { color: #E6EDF3 } /* Name.Other */
# .ca .py { color: #79C0FF } /* Name.Property */
# .ca .nt { color: #7EE787 } /* Name.Tag */
# .ca .nv { color: #79C0FF } /* Name.Variable */
# .ca .ow { color: #FF7B72; font-weight: bold } /* Operator.Word */
# .ca .pm { color: #E6EDF3 } /* Punctuation.Marker */
# .ca .w { color: #6E7681 } /* Text.Whitespace */
# .ca .mb { color: #A5D6FF } /* Literal.Number.Bin */
# .ca .mf { color: #A5D6FF } /* Literal.Number.Float */
# .ca .mh { color: #A5D6FF } /* Literal.Number.Hex */
# .ca .mi { color: #A5D6FF } /* Literal.Number.Integer */
# .ca .mo { color: #A5D6FF } /* Literal.Number.Oct */
# .ca .sa { color: #79C0FF } /* Literal.String.Affix */
# .ca .sb { color: #A5D6FF } /* Literal.String.Backtick */
# .ca .sc { color: #A5D6FF } /* Literal.String.Char */
# .ca .dl { color: #79C0FF } /* Literal.String.Delimiter */
# .ca .sd { color: #A5D6FF } /* Literal.String.Doc */
# .ca .s2 { color: #A5D6FF } /* Literal.String.Double */
# .ca .se { color: #79C0FF } /* Literal.String.Escape */
# .ca .sh { color: #79C0FF } /* Literal.String.Heredoc */
# .ca .si { color: #A5D6FF } /* Literal.String.Interpol */
# .ca .sx { color: #A5D6FF } /* Literal.String.Other */
# .ca .sr { color: #79C0FF } /* Literal.String.Regex */
# .ca .s1 { color: #A5D6FF } /* Literal.String.Single */
# .ca .ss { color: #A5D6FF } /* Literal.String.Symbol */
# .ca .bp { color: #E6EDF3 } /* Name.Builtin.Pseudo */
# .ca .fm { color: #D2A8FF; font-weight: bold } /* Name.Function.Magic */
# .ca .vc { color: #79C0FF } /* Name.Variable.Class */
# .ca .vg { color: #79C0FF } /* Name.Variable.Global */
# .ca .vi { color: #79C0FF } /* Name.Variable.Instance */
# .ca .vm { color: #79C0FF } /* Name.Variable.Magic */
# .ca .il { color: #A5D6FF } /* Literal.Number.Integer.Long */
# .ca pre{margin:0;line-height:1.5rem}
# .ca .hll{background:#3d4626!important;display:block;width:100%}
# .ca .linenos{background:transparent!important}
# </style>
# <div style="display:inline-flex;background:#0d1117;border-radius:8px;border:1px solid #444;margin:10px 0;font-family:monospace">
# <div style="flex:3;overflow-x:auto"><div class="ca"><pre><span></span><span class="linenos"> 1</span><span class="k">class</span><span class="w"> </span><span class="nc">TinyAgent</span><span class="p">:</span>
# <span class="linenos"> 2</span><span class="w">    </span><span class="sd">&quot;&quot;&quot;The TinyAgent is a minimal agent framework.</span>
# <span class="linenos"> 3</span>
# <span class="linenos"> 4</span><span class="sd">    This is the foundation that we will build upon in later chapters.</span>
# <span class="linenos"> 5</span><span class="sd">    &quot;&quot;&quot;</span>
# <span class="linenos"> 6</span>
# <span class="linenos"> 7</span>    <span class="k">def</span><span class="w"> </span><span class="fm">__init__</span><span class="p">(</span><span class="bp">self</span><span class="p">):</span>
# <span class="linenos"> 8</span>        <span class="bp">self</span><span class="o">.</span><span class="n">llm</span> <span class="o">=</span> <span class="kc">None</span>  <span class="c1"># Chapter 2 &amp; 3: Add LLM</span>
# <span class="linenos"> 9</span>        <span class="bp">self</span><span class="o">.</span><span class="n">memory</span> <span class="o">=</span> <span class="kc">None</span>  <span class="c1"># Chapter 4: Add Memory</span>
# <span class="linenos">10</span>        <span class="bp">self</span><span class="o">.</span><span class="n">tools</span> <span class="o">=</span> <span class="kc">None</span>  <span class="c1"># Chapter 5: Add Tools</span>
# <span class="linenos">11</span>        <span class="bp">self</span><span class="o">.</span><span class="n">planner</span> <span class="o">=</span> <span class="kc">None</span>  <span class="c1"># Chapter 6: Add Planning</span>
# <span class="linenos">12</span>        <span class="bp">self</span><span class="o">.</span><span class="n">reflector</span> <span class="o">=</span> <span class="kc">None</span>  <span class="c1"># Chapter 6: Add Reflection</span>
# <span class="linenos">13</span>
# <span class="hll"><span class="linenos">14</span>    <span class="k">def</span><span class="w"> </span><span class="nf">run</span><span class="p">(</span><span class="bp">self</span><span class="p">,</span> <span class="n">task</span><span class="p">:</span> <span class="nb">str</span><span class="p">)</span> <span class="o">-&gt;</span> <span class="nb">str</span><span class="p">:</span>
# </span><span class="hll"><span class="linenos">15</span><span class="w">        </span><span class="sd">&quot;&quot;&quot;Run the agent on a task.&quot;&quot;&quot;</span>
# </span><span class="hll"><span class="linenos">16</span>        <span class="k">return</span> <span class="bp">self</span><span class="o">.</span><span class="n">_step</span><span class="p">(</span><span class="

# %% [markdown]
# Then, all that is left to do is "run" the Agent, which gives back nothing more than what is has received. After all, without a "brain", there is nothing more than your `TinyAgent` can do:

# %%
agent = TinyAgent()
agent.run("What is 2 + 2?")
# Out:
# 'Received: What is 2 + 2?'

# %% [markdown]
# So... let's continue to the next chapter where we can give it a "brain"!
