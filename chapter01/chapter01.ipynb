# %% [markdown]
# <h1>Chapter 1 - Introducing Agents</h1>
# <i>Exploring AI Agents</i>
#
#
# <a href="..."><img src="https://img.shields.io/badge/Buy%20the%20Book!-grey?logo=amazon"></a>
# <a href="..."><img src="https://img.shields.io/badge/O'Reilly-white.svg?logo=..."></a>
# <a href="..."><img src="https://img.shields.io/badge/GitHub%20Repository-black?logo=github"></a>
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](...)
#
# ---
#
# This notebook is for Chapter 1 of the [An Illustrated Guide to AI Agents](...) book by [Maarten Grootendorst](https://www.linkedin.com/in/mgrootendorst/) and [Jay Alammar](https://www.linkedin.com/in/jalammar).
#
# ---
#
# <a href="...">
# <img src="https://learning.oreilly.com/covers/urn:orm:book:9798341662681/400w/" width="350"/></a>

# %% [markdown]
# ### **[OPTIONAL]** - Installing Packages on Google Colab <img src="https://upload.wikimedia.org/wikipedia/commons/d/d0/Google_Colaboratory_SVG_Logo.svg" width=100>
#
# If you are viewing this notebook on Google Colab (or any other cloud vendor), you need to **uncomment and run** the following codeblock to install the dependencies for this chapter:

# %% [markdown]
# ---
#
# 💡 **NOTE**: We will want to use a GPU to run the examples in this notebook. In Google Colab, go to
# **Runtime > Change runtime type > Hardware accelerator > GPU > GPU type > T4**.
#
# ---

# %%
# %%capture
# !pip install illustrated-agents

# %% [markdown]
# <hr style="height: 5px; border: none; border-radius: 5px; background: linear-gradient(to right, #000000, #7D7D7D);" />

# %% [markdown]
# ## 1 - Building an `Agent` from Scratch
#
# Throughout this book, we will explore various components of Agent, which together make up the `TinyAgent` which is given in the `\tinyagent` folder.
# This code builds an Agent (called `TinyAgent`) entirely from scratch, using only API calls to the LLM.
#
# To do so, we make use of a highly modular and educational structure of our `TinyAgent` that focuses on understanding the vital components of an Agent.
# As such, we start this chapter with an `agent.py` and slowly build it up by adding components:
#
# ![../images/overview.png](../images/overview.png)
#
# Each chapter builds on the previous one, starting with this one which creates the `agent.py` file. In each chapter, we add a module to the `agent.py` framework so that we can improve its behavior. We will be iteratively updating `agent.py` to implement this behavior:
#
# | Chapter | Module Added | Capability |
# |---------|--------------|------------|
# | 1 | (skeleton) | Basic structure with placeholders |
# | 2 | `llm.py` | Can query an LLM (stateless) |
# | 3 | - | Learn to do reasoning (both native and prompted) |
# | 4 | `memory.py` | Remembers conversation history |
# | 5 | `tools.py` & `toolbox.py` | Toolcalling capabilities (both native and prompted) |
# | 6 | `planning.py` | ReAct loop (multi-step reasoning) |
# | 8 | `coordinator.py` | Multi-agent collaboration |
#
# LLMs these days have been trained to perform native tool calling and reasoning. Although this makes it easier to showcase these capabilities, it is a bit of a black box to understand **how** they are reasoning and performing tool calls. For that reason, we thought it would be interesting in this book to show how to use a model that cannot reason or call tools natively and have it do that through prompt engineering. We hope that it will help you understand what it actually means for a model to call a tool or to reason. However, that doesn't mean we can forget the models that **can** perform native reasoning and tool calling.
#
# Therefore, we decided to show you both! Throughout the book we will demonstrate both prompt-based and native reasoning and tool calling capabilities. By doing it yourself, we hope it will help you get insight into how these newer models have learned to perform native reasoning and tool calling.
#
# As such, we choose two models throughout this book, one that cannot natively perform any reasoning or tool calling whatsoever (Gemma 3) and one that has been trained specifically to perform agentic tasks through reasoning and tool calling (Gemma 4).
#
# ![../images/evolution.png](../images/evolution.png)
#
# We strongly believe that having a model like Gemma 3 perform tool calling is a wonderful way to understand what is needed in the process of calling a tool. It will answer questions like; What format do we need to call a tool? Why is XML better than JSON for multi-line texts in tool calls?
#
# By getting your hands dirty, you will learn more about the complexities of these capabilities than using a model that does it all for you! As such, we will start with Gemma 3 and slowly built up to Gemma 4. We will demonstrate both prompt-based and native capabilities and slowly built up so that you will get a thorough understanding of these techniques.

# %% [markdown]
# ## 2 - The `TinyAgent`
#
# Let's start with building our `TinyAgent`. This class will start with the LLM we defined above and nothing more. It technically cannot be considered an Agent yet until we have added all above components.
#
# ![../images/ch1.png](../images/ch1.png)

# %% [markdown]
# That said, let's build the scaffolding of this `TinyAgent`. There are several components that we can already define without using any LLM, namely:
#
# * Attributes that we add later on
# * `run` which is the main function to run the Agent
# * `_step` which is a single step of the Agent (it may run for multiple steps)

# %%
class TinyAgent:
    """A minimal, modular, and educational agent framework."""

    def __init__(self):
        self.llm = None  # Chapter 2 & 3: Add LLM
        self.memory = None  # Chapter 4: Add Memory
        self.tools = None  # Chapter 5: Add Tools
        self.planner = None  # Chapter 6: Add Planning
        self.skills = None  # Chapter 6: Add Skills

    def run(self, task: str) -> str:
        """Run the agent on a task."""
        return self._step(task)

    def _step(self, task: str) -> str:
        """Perform a single step."""
        # Placeholder - will be implemented in later chapters
        return f"Received: {task}"

    def _execute_action(self, action: str) -> str | None:
        """Execute a tool action."""
        # Placeholder - will be implemented in later chapters
        return f"Executed action: {action}"

# %% [markdown]
# Looking a little bit closer at each function gives us more clarity with respect to the difference between the `run` and a single `_step`:

# %%
from illustrated_agents.chapters.ch1 import agent_annotated; agent_annotated
# Out:
# <style>
# pre{line-height:1.5em!important}
# pre { line-height: 125%; }
# td.linenos .normal { color: #6e7681; background-color: #0d1117; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #6e7681; background-color: #0d1117; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #e6edf3; background-color: #6e7681; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #e6edf3; background-color: #6e7681; padding-left: 5px; padding-right: 5px; }
# .ca-fce987a0 .hll { background-color: #6e7681 }
# .ca-fce987a0 { background: #0d1117; color: #E6EDF3 }
# .ca-fce987a0 .c { color: #8B949E; font-style: italic } /* Comment */
# .ca-fce987a0 .err { color: #F85149 } /* Error */
# .ca-fce987a0 .esc { color: #E6EDF3 } /* Escape */
# .ca-fce987a0 .g { color: #E6EDF3 } /* Generic */
# .ca-fce987a0 .k { color: #FF7B72 } /* Keyword */
# .ca-fce987a0 .l { color: #A5D6FF } /* Literal */
# .ca-fce987a0 .n { color: #E6EDF3 } /* Name */
# .ca-fce987a0 .o { color: #FF7B72; font-weight: bold } /* Operator */
# .ca-fce987a0 .x { color: #E6EDF3 } /* Other */
# .ca-fce987a0 .p { color: #E6EDF3 } /* Punctuation */
# .ca-fce987a0 .ch { color: #8B949E; font-style: italic } /* Comment.Hashbang */
# .ca-fce987a0 .cm { color: #8B949E; font-style: italic } /* Comment.Multiline */
# .ca-fce987a0 .cp { color: #8B949E; font-weight: bold; font-style: italic } /* Comment.Preproc */
# .ca-fce987a0 .cpf { color: #8B949E; font-style: italic } /* Comment.PreprocFile */
# .ca-fce987a0 .c1 { color: #8B949E; font-style: italic } /* Comment.Single */
# .ca-fce987a0 .cs { color: #8B949E; font-weight: bold; font-style: italic } /* Comment.Special */
# .ca-fce987a0 .gd { color: #FFA198; background-color: #490202 } /* Generic.Deleted */
# .ca-fce987a0 .ge { color: #E6EDF3; font-style: italic } /* Generic.Emph */
# .ca-fce987a0 .ges { color: #E6EDF3; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .ca-fce987a0 .gr { color: #FFA198 } /* Generic.Error */
# .ca-fce987a0 .gh { color: #79C0FF; font-weight: bold } /* Generic.Heading */
# .ca-fce987a0 .gi { color: #56D364; background-color: #0F5323 } /* Generic.Inserted */
# .ca-fce987a0 .go { color: #8B949E } /* Generic.Output */
# .ca-fce987a0 .gp { color: #8B949E } /* Generic.Prompt */
# .ca-fce987a0 .gs { color: #E6EDF3; font-weight: bold } /* Generic.Strong */
# .ca-fce987a0 .gu { color: #79C0FF } /* Generic.Subheading */
# .ca-fce987a0 .gt { color: #FF7B72 } /* Generic.Traceback */
# .ca-fce987a0 .g-Underline { color: #E6EDF3; text-decoration: underline } /* Generic.Underline */
# .ca-fce987a0 .kc { color: #79C0FF } /* Keyword.Constant */
# .ca-fce987a0 .kd { color: #FF7B72 } /* Keyword.Declaration */
# .ca-fce987a0 .kn { color: #FF7B72 } /* Keyword.Namespace */
# .ca-fce987a0 .kp { color: #79C0FF } /* Keyword.Pseudo */
# .ca-fce987a0 .kr { color: #FF7B72 } /* Keyword.Reserved */
# .ca-fce987a0 .kt { color: #FF7B72 } /* Keyword.Type */
# .ca-fce987a0 .ld { color: #79C0FF } /* Literal.Date */
# .ca-fce987a0 .m { color: #A5D6FF } /* Literal.Number */
# .ca-fce987a0 .s { color: #A5D6FF } /* Literal.String */
# .ca-fce987a0 .na { color: #E6EDF3 } /* Name.Attribute */
# .ca-fce987a0 .nb { color: #E6EDF3 } /* Name.Builtin */
# .ca-fce987a0 .nc { color: #F0883E; font-weight: bold } /* Name.Class */
# .ca-fce987a0 .no { color: #79C0FF; font-weight: bold } /* Name.Constant */
# .ca-fce987a0 .nd { color: #D2A8FF; font-weight: bold } /* Name.Decorator */
# .ca-fce987a0 .ni { color: #FFA657 } /* Name.Entity */
# .ca-fce987a0 .ne { color: #F0883E; font-weight: bold } /* Name.Exception */
# .ca-fce987a0 .nf { color: #D2A8FF; font-weight: bold } /* Name.Function */
# .ca-fce987a0 .nl { color: #79C0FF; font-weight: bold } /* Name.Label */
# .ca-fce987a0 .nn { color: #FF7B72 } /* Name.Namespace */
# .ca-fce987a0 .nx { color: #E6EDF3 } /* Name.Other */
# .ca-fce987a0 .py { color: #79C0FF } /* Name.Property */
# .ca-fce987a0 .nt { color: #7EE787 } /* Name.Tag */
# .ca-fce987a0 .nv { color: #79C0FF } /* Name.Variable */
# .ca-fce987a0 .ow { color: #FF7B72; font-weight: bold } /* Operator.Word */
# .ca-fce987a0 .pm { color: #E6EDF3 } /* Punctuation.Marker */
# .ca-fce987a0 .w { color: #6E7681 } /* Text.Whitespace */
# .ca-fce987a0 .mb { color: #A5D6FF } /* Literal.Number.Bin */
# .ca-fce987a0 .mf { color: #A5D6FF } /* Literal.Number.Float */
# .ca-fce987a0 .mh { color: #A5D6FF } /* Literal.Number.Hex */
# .ca-fce987a0 .mi { color: #A5D6FF } /* Literal.Number.Integer */
# .ca-fce987a0 .mo { color: #A5D6FF } /* Literal.Number.Oct */
# .ca-fce987a0 .sa { color: #79C0FF } /* Literal.String.Affix */
# .ca-fce987a0 .sb { color: #A5D6FF } /* Literal.String.Backtick */
# .ca-fce987a0 .sc { color: #A5D6FF } /* Literal.String.Char */
# .ca-fce987a0 .dl { color: #79C0FF } /* Literal.String.Delimiter */
# .ca-fce987a0 .sd { color: #A5D6FF } /* Literal.String.Doc */
# .ca-fce987a0 .s2 { color: #A5D6FF } /* Literal.String.Double */
# .ca-fce987a0 .se { color: #79C0FF } /* Literal.String.Escape */
# .ca-fce987a0 .sh { color: #79C0FF } /* Literal.String.Heredoc */
# .ca-fce987a0 .si { color: #A5D6FF } /* Literal.String.Interpol */
# .ca-fce987a0 .sx { color: #A5D6FF } /* Literal.String.Other */
# .ca-fce987a0 .sr { color: #79C0FF } /* Literal.String.Regex */
# .ca-fce987a0 .s1 { color: #A5D6FF } /* Literal.String.Single */
# .ca-fce987a0 .ss { color: #A5D6FF } /* Literal.String.Symbol */
# .ca-fce987a0 .bp { color: #E6EDF3 } /* Name.Builtin.Pseudo */
# .ca-fce987a0 .fm { color: #D2A8FF; font-weight: bold } /* Name.Function.Magic */
# .ca-fce987a0 .vc { color: #79C0FF } /* Name.Variable.Class */
# .ca-fce987a0 .vg { color: #79C0FF } /* Name.Variable.Global */
# .ca-fce987a0 .vi { color: #79C0FF } /* Name.Variable.Instance */
# .ca-fce987a0 .vm { color: #79C0FF } /* Name.Variable.Magic */
# .ca-fce987a0 .il { color: #A5D6FF } /* Literal.Number.Integer.Long */
# .ca-fce987a0{background:#0d1117!important;color:#e6edf3!important;font-size:14px}
# .ca-fce987a0 pre{margin:0;padding:0;line-height:1.5em!important;background:#0d1117!important;color:#e6edf3!important}
# .ca-fce987a0 code{background:#0d1117!important;color:#e6edf3!important}
# .ca-fce987a0 .hll{background:#3d4626!important;display:block;width:100%}
# .ca-fce987a0 .linenos{background:#0d1117!important;color:#e6edf3!important}
# </style>
# <div style="display:inline-flex;align-items:flex-start;background:#0d1117;border-radius:8px;border:1px solid #444;margin:10px 0;font-family:monospace;font-size:14px;line-height:1.5em">
# <div style="flex:3;overflow-x:auto;background:#0d1117"><div class="ca-fce987a0"><pre><span class="linenos"> 1</span><span class="k">class</span><span class="w"> </span><span class="nc">TinyAgent</span><span class="p">:</span>
# <span class="linenos"> 2</span><span class="w">    </span><span class="sd">&quot;&quot;&quot;A minimal, modular, and educational agent framework.&quot;&quot;&quot;</span>
# <span class="linenos"> 3</span>
# <span class="linenos"> 4</span>    <span class="k">def</span><span class="w"> </span><span class="fm">__init__</span><span class="p">(</span><span class="bp">self</span><span class="p">):</span>
# <span class="linenos"> 5</span>        <span class="bp">self</span><span class="o">.</span><span class="n">llm</span> <span class="o">=</span> <span class="kc">None</span>  <span class="c1"># Chapter 2 &amp; 3: Add LLM</span>
# <span class="linenos"> 6</span>        <span class="bp">self</span><span class="o">.</span><span class="n">memory</span> <span class="o">=</span> <span class="kc">None</span>  <span class="c1"># Chapter 4: Add Memory</span>
# <span class="linenos"> 7</span>        <span class="bp">self</span><span class="o">.</span><span class="n">tools</span> <span class="o">=</span> <span class="kc">None</span>  <span class="c1"># Chapter 5: Add Tools</span>
# <span class="linenos"> 8</span>        <span class="bp">self</span><span class="o">.</span><span class="n">planner</span> <span class="o">=</span> <span class="kc">None</span>  <span class="c1"># Chapter 6: Add Planning</span>
# <span class="linenos"> 9</span>        <span class="bp">self</span><span class="o">.</span><span class="n">skills</span> <span class="o">=</

# %% [markdown]
# Then, all that is left to do is "run" the Agent, which gives back nothing more than what is has received. After all, without a "brain", there is nothing more than your `TinyAgent` can do:

# %%
agent = TinyAgent()
agent.run("What is 2 + 2?")
# Out:
# 'Received: What is 2 + 2?'

# %% [markdown]
# So... let's continue to the next chapter where we can give it a "brain"!

# %% [markdown]
# <hr style="height: 5px; border: none; border-radius: 5px; background: linear-gradient(to right, #000000, #7D7D7D);" />

# %% [markdown]
# # What We Built
#
# We will end each chapter by giving you an overview of what we built. Building your `TinyAgent` from scratch and through modularity means that we can continuously track which pieces of code we have updated and how.
#
# All code created in this chapter tutorials can be seen in `src/illustrated_agents` where you will find an overview like this:

# %% [markdown]
#   ```
#   TinyAgent
#   ├── __init__.py
#   ├── agent.py
#   ├── cli.py
#   ├── display.py
#   ├── llm.py
#   ├── memory.py
#   ├── planning.py
#   ├── skills.py
#   ├── toolbox.py
#   ├── tools.py
#   ├── trajectory.py
#   └── utils.py
#   ```

# %% [markdown]
# The idea is that we slowly built up each of those `.py` files and explain how they relate to Agents!
#
# In this chapter, we covered the basic structure of your `TinyAgent`, which means that you started taking your first steps into building an agent from scratch, congratulations :)
#
# Run the following for an overview:

# %%
from illustrated_agents.chapters.ch1 import what_we_built; what_we_built
# Out:
# ╭───────────────────────────────────────────────── What We Built ─────────────────────────────────────────────────╮
# │ TinyAgent                                                                                                       │
# │ └── agent.py ← New (`TinyAgent` skeleton - The start of something cool ;))                                      │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# # What's Next
#
# In the next chapter, we will cover how LLMs work and which you can choose throughout this book.
